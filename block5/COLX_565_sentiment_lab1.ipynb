# %% [markdown]
# # COLX 565 Lab Assignment 1: Polarity Lexicons (Cheat sheet)

# %% [markdown]
# ## Assignment Objectives

# %% [markdown]
# In this assignment you will
# - Compare sentiment lexicons for sentiment analysis
# - Apply contextual valence shifters to improve polarity detection
# - Identify challenges in lexicon-based sentiment analysis by carrying out error analysis

# %% [markdown]
# - Ex1: Human-built lexicons
#     - NLTK's `opinion_lexicon`
#     - `VADER` lexicon
#     - `SO-CAL lexicon` *
#     - `Subjectivity lexicon`
#     - `evaluate_lexicon` on "Sentence Polarity" and "Pros and Cons" in NLTK
# - Ex2: Induced lexicons
#     - `SentiWordNet`
#     - Semantic Axis using `word2vec` (See 25.4.1 in https://web.stanford.edu/~jurafsky/slp3/25.pdf)
#     - `random_walk` (optional)
#     - `intrinsic_evaluate` with `SO-CAL lexicon`
# - Ex3: Valence shifters
#     - intensification from `SO-CAL`
#     - negation (*no* and *not*)
#     - `evaluate_lexicon` with intensification and/or negation
# - Ex4: Error analysis
#     - print out sentences which are not labeled correctly (eg. negative)
#     - identify three categories of errors (manually)

# %% [markdown]
# ## Getting Started

# %% [markdown]
# You need to have downloaded the following NLTK resources:

# %%
#provided code
import nltk
nltk.download("sentence_polarity")
nltk.download("pros_cons")
nltk.download("opinion_lexicon")
nltk.download("sentiwordnet")
nltk.download("word2vec_sample")
# Out:
# [nltk_data] Downloading package sentence_polarity to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package sentence_polarity is already up-to-date!
# [nltk_data] Downloading package pros_cons to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package pros_cons is already up-to-date!
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# [nltk_data] Downloading package word2vec_sample to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package word2vec_sample is already up-to-date!
# True

# %% [markdown]
# Run the code below to access relevant modules (you can add to this as needed)

# %%
#provided code
import gensim
from nltk.data import find
from nltk.corpus import sentence_polarity,pros_cons,opinion_lexicon
from nltk.corpus import sentiwordnet as swn
from nltk.corpus import wordnet as wn
import numpy as np
from scipy.spatial.distance import cosine
from scipy.sparse import csr_matrix, lil_matrix
import urllib.request

# %% [markdown]
# ## Tidy Submission
#
# rubric={mechanics:1}

# %% [markdown]
# To get the marks for tidy submission:
#
# - Submit the assignment by filling in this jupyter notebook with your answers embedded
# - Be sure to follow the [general lab instructions](https://ubc-mds.github.io/resources_pages/general_lab_instructions)

# %% [markdown]
# ### Exercise 1: Human-built lexicons

# %% [markdown]
# #### Exercise 1.1:
# rubric={accuracy:1}
#
# Access the `opinion_lexicon` included with NLTK, and convert the lists of words into a dictionary where the positive words have the value "1" and negative words have the value "-1"

# %% [markdown]
# https://www.nltk.org/_modules/nltk/corpus/reader/opinion_lexicon.html
#
# ```
# from nltk.corpus import opinion_lexicon
#
# def positive(self):
#     """
#     Return all positive words in alphabetical order.
#     """
#     a+
#     abundance
#     acclaim
#     ...
#
# def negative(self):
#     """
#     Return all negative words in alphabetical order.
#     """
#     abnormal
#     abolish
#     abominable
#     ...
# ```
#
# For example:
#
# ```
# {"good": 1,
#  "bad": -1,
#  "terrible": -1,
#  ...
#  }
#  ```

# %%
NLTK_lexicon = {}

#Your code here
#Your code here

# %%
print("a+", NLTK_lexicon["a+"])
print("abnormal", NLTK_lexicon["abnormal"])
# Out:
# a+ 1
# abnormal -1

# %% [markdown]
# #### Exercise 1.2:
# rubric={accuracy:1}
#
# Next, get the crowdsourced [`VADER`](https://github.com/cjhutto/vaderSentiment) lexicon by directly accessing the github page [here](https://raw.githubusercontent.com/cjhutto/vaderSentiment/master/vaderSentiment/vader_lexicon.txt). In the tab-delimited format, the lexical entry is the first item in each row, and the second item is the semantic orientation, those are the only two bits of information you need to store, again you should store it in a dictionary.

# %% [markdown]
# VADER (Valence Aware Dictionary and Entiment Reasoner) lexicon:  https://github.com/cjhutto/vaderSentiment
#
# Hutto, C.J. & Gilbert, E.E. (2014). VADER: A Parsimonious Rule-based Model for Sentiment Analysis of Social Media Text. *Proceedings of the Eighth International Conference on Weblogs and Social Media (ICWSM-14)*. Ann Arbor, MI, June 2014.
#
# ```
# OK      OK      KO      KO
# --------------------------------------------------------------------------------
# :(      -1.9    1.13578 [-2, -3, -2, 0, -1, -1, -2, -3, -1, -4]
# :)      2.0     1.18322 [2, 2, 1, 1, 1, 1, 4, 3, 4, 1]
# happy   2.7     0.9     [2, 2, 2, 4, 2, 4, 3, 4, 2, 2]
# unhappy -1.8    0.6     [-2, -2, -1, -3, -2, -2, -2, -1, -2, -1]
# ```

# %%
VADER_lexicon = {}

location = "https://raw.githubusercontent.com/cjhutto/vaderSentiment/master/vaderSentiment/vader_lexicon.txt"
f = urllib.request.urlopen(location)
#Your code here
#Your code here

# %%
print(":(", VADER_lexicon[":("])
print(":)", VADER_lexicon[":)"])
# Out:
# :( -1.9
# :) 2.0

# %% [markdown]
# The `compound` score is computed by summing the valence scores of each word in the lexicon:
#
#
# * positive sentiment: compound score $\geq$ 0.05
# * neutral sentiment:  -0.05 $<$ compound score  $<$ 0.05
# * negative sentiment: compound score $\leq$ -0.05
#
# ```
# > VADER is smart, handsome, and funny.
# {'pos': 0.746, 'compound': 0.8316, 'neu': 0.254, 'neg': 0.0}
# > VADER is not smart, handsome, nor funny.
# {'pos': 0.0, 'compound': -0.7424, 'neu': 0.354, 'neg': 0.646}
# ```

# %% [markdown]
# #### Exercise 1.3:
# rubric={accuracy:1}
#
# Now access the [SO-CAL lexicon](https://github.com/sfu-discourse-lab/SO-CAL/tree/master/Resources/dictionaries/English), which, like VADER, you should pull directly from the internet rather than saving any files. Your code will be very similar to the VADER, but note that there are actually 4 lexicons, one for each open-class part of speech, that you should collapse into a single Python dictionary (it's okay if you just overwrite any duplicates, i.e. the same word appearing in different parts of speech).

# %% [markdown]
# SO-CAL is the "Semantic Orientation (SO)" CALculator https://github.com/sfu-discourse-lab/SO-CAL since 2004.
#
# Taboada, M., Brooke, J., Tofiloski, M., Voll, K. and Stede, M. (2011) Lexicon-Based Methods for Sentiment Analysis. *Computational Linguistics* 37(2): 267-307.
#
#
# **4  open-class parts of speech**: https://github.com/sfu-discourse-lab/SO-CAL/tree/master/Resources/dictionaries/English
#
# ```
# adj_dictionary1.11.txt
# adv_dictionary1.11.txt
# google_dict.txt
# int_dictionary1.11.txt
# noun_dictionary1.11.txt
# verb_dictionary1.11.txt
# ```

# %%
SO_CAL_lexicon = {}

location = "https://raw.githubusercontent.com/sfu-discourse-lab/SO-CAL/master/Resources/dictionaries/English/"
#Your code here
#Your code here
# Out:
# processing... adj_dictionary1.11.txt
# processing... noun_dictionary1.11.txt
# processing... verb_dictionary1.11.txt
# processing... adv_dictionary1.11.txt

# %%
assert SO_CAL_lexicon["unrealistic"] == -1.0

# %% [markdown]
# #### Exercise 1.4:
# rubric={accuracy:2}
#
# The last lexicon you have to include in this analysis is the [Subjectivity lexicon](http://mpqa.cs.pitt.edu/lexicons/subj_lexicon/). Since downloading it is not entirely trivial we have included it in your repo. It has very different format than the other lexicons, with key/value pairs which have the information you need. You are interested here in "word1" which provides the word, "priorpolarity" which gives the polarity, and "type" which gives information about Strength. It includes neutral words that can be ignored. Otherwise, you can treat it somewhat similarly to the NLTK lexicon, except words with strong subjectivity should have values of 2/-2, instead of the 1/-1.

# %% [markdown]
# Subjectivity lexicon http://mpqa.cs.pitt.edu/lexicons/subj_lexicon/ (Note that `subjectivity.txt` is provided)
#
#
# T. Wilson, J. Wiebe, and P. Hoffmann (2005). Recognizing Contextual Polarity in Phrase-Level Sentiment Analysis. *Proceedings of Human Language Technology Conference and Conference on Empirical Methods in Natural Language Processing*. https://www.aclweb.org/anthology/H05-1044/
#
# ```
# strength        length word          pos      stemmed    polarity
# --------------------------------------------------------------------------------
# type=strongsubj len=1  word1=happy   pos1=adj stemmed1=n priorpolarity=positive
# type=strongsubj len=1  word1=unhappy pos1=adj stemmed1=n priorpolarity=negative
#
#
#
#
# ```
# - `subjectivity.txt` is delimited with " "
# - `positive` or `negative` =  2/-2 if `type=strongsubj`, otherwise = 1/-1
# - neutral words can be ignored
#
# ```
#
# % cut -f6 -d" " subjectivity.txt | sort | uniq -c
#    1 ppriorpolarity=negative
#   21 priorpolarity=both
# 4911 priorpolarity=negative
#  570 priorpolarity=neutral
# 2718 priorpolarity=positive
#
# % cut -f1 -d" " subjectivity.txt | sort | uniq -c
# 5569 type=strongsubj
# 2652 type=weaksubj
# ```

# %%
subjectivity_lexicon = {}

f = open("subjectivity.txt")
#Your code here
#Your code here

# %%
print("happy", subjectivity_lexicon["happy"])
print("unhappy", subjectivity_lexicon["unhappy"])
# Out:
# happy 2
# unhappy -2

# %% [markdown]
# #### 1.5
# rubric={accuracy:1,quality:1}
#
# Present some basic stats for these lexicons. You should include the total number of words, the number of positive and negative words, and the range of semantic orientation (SO) values.

# %%
def get_stats(lexicon):
    '''
    A function that, when given a lexicon, will print out the total number of words in the lexicon,
    the number of positive words, the number of negative words, and the range of the SO values.
    '''
    #Your code here
    #Your code here 
    
print("NLTK lexicon")
get_stats(NLTK_lexicon)

print("VADER lexicon")
get_stats(VADER_lexicon)

print("SO-CAL lexicon")
get_stats(SO_CAL_lexicon)

print("Subjectivity lexicon")
get_stats(subjectivity_lexicon)
# Out:
# NLTK lexicon
# total words: 6786
# positive words: 2003
# negative words: 4783
# range -1 to 1
# VADER lexicon
# total words: 7506
# positive words: 3337
# negative words: 4169
# range -3.9 to 3.4
# SO-CAL lexicon
# total words: 6091
# positive words: 2478
# negative words: 3613
# range -5.0 to 5.0
# Subjectivity lexicon
# total words: 6451
# positive words: 2301
# negative words: 4150
# range -2 to 2

# %% [markdown]
# #### 1.6
# rubric={accuracy:2,quality:2}
#
# Evaluate these four lexicons against two corpora included in NLTK, the `sentence_polarity` corpus (snippets from Rotten Tomatoes) and `pros_cons` (Pros and cons from camera reviews). You can just sum the SO of words in each document and consider it positive if the SO is greater than zero, and negative if it is less than zero. For each corpus and each lexicon, present an overall accuracy as well as an accuracy for each type of text (positive and negative). You should modularize your code and avoid repetition. (HINT: to get full quality points, you'll want at least two functions: one that evaluates a given corpus with a given lexicon and another that calculates the SO for a particular text. Within the former function, it might be easier to iterate over positive and negative sentences in separate loops--remember the *categories* keyword for NLTK corpora. It is possible to be modular here by taking advantage of the fact that although the two corpora have different labels for positive and negative, the negative labels for both corpora are \*corpus\*.categories()\[0\] and the positive labels for both are \*corpus\*.categories()\[1\])

# %%
def calculate_SO(text,lexicon,ints=None,negs=None):
    '''calculate a semantic orientation for a text as the sum of the semantic orientation
    of the words of the text as provided by lexicon'''
    
    #Your code here
    #Your code here

def evaluate_lexicon(corpus,lexicon,ints=None,negs=None):
    '''given a lexicon and a sentiment analysis corpus with labels, calculate and print the
    percentage accuracy in polarity classification for each class, and overall'''
    
    pos_total = 0
    neg_total = 0
    neg_correct = 0
    pos_correct = 0

    #Your code here
    #Your code here

    print("-----")    
    print("positive correct")
    print(pos_correct/pos_total)    
    print("negative correct")
    print(neg_correct/neg_total)
    print("total")
    print((pos_correct + neg_correct)/(neg_total + pos_total))

    print("-------------------------")

# %% [markdown]
# ```
# from nltk.corpus import sentence_polarity, pros_cons
#
# corpus.sents(categories=corpus.categories()[0]) #-> negative sentences
# corpus.sents(categories=corpus.categories()[1]) #-> positive sentences
# ```

# %%
print("Positive sentence from the 'sentence_polarity' corpus:")

text = sentence_polarity.sents(categories=sentence_polarity.categories()[1])[0]
print(text)

print(sum(NLTK_lexicon.get(word.lower(),0) for word in text))
print(sum(VADER_lexicon.get(word.lower(),0) for word in text))
print(sum(SO_CAL_lexicon.get(word.lower(),0) for word in text))
print(sum(subjectivity_lexicon.get(word.lower(),0) for word in text))
# Out:
# Positive sentence from the 'sentence_polarity' corpus:
# ['the', 'rock', 'is', 'destined', 'to', 'be', 'the', '21st', "century's", 'new', '"', 'conan', '"', 'and', 'that', "he's", 'going', 'to', 'make', 'a', 'splash', 'even', 'greater', 'than', 'arnold', 'schwarzenegger', ',', 'jean-claud', 'van', 'damme', 'or', 'steven', 'segal', '.']
# 0
# 1.5
# 6.0
# 2

# %%
# nltk.download("sentence_polarity")
# nltk.download("pros_cons")

#Provided code
for ev_name,corpus in [("Sentence Polarity",sentence_polarity),
                        ("Pros and Cons",pros_cons)]:
    print("******")
    print(ev_name)
    for lex_name,lexicon in [("NLTK",NLTK_lexicon),("VADER",VADER_lexicon),
                             ("SO-CAL",SO_CAL_lexicon),("Subjectivity",subjectivity_lexicon)]:
        print(lex_name)
        evaluate_lexicon(corpus,lexicon)
#Provided code
# Out:
# ******
# Sentence Polarity
# NLTK
# -----
# positive correct
# 0.5670605890076909
# negative correct
# 0.4483211404989683
# total
# 0.5076908647533296
# VADER
# -----
# positive correct
# 0.708309885574939
# negative correct
# 0.3676608516225849
# total
# 0.537985368598762
# SO-CAL
# -----
# positive correct
# 0.7454511348715063
# negative correct
# 0.4558244231851435
# total
# 0.6006377790283249
# Subjectivity
# -----
# positive correct
# 0.6479084599512287
# negative correct
# 0.44982179703620334
# total
# 0.548865128493716
# ******
# Pros and Cons
# NLTK
# -----
# positive correct
# 0.7653443766346992
# negative correct
# 0.43562241116197953
# total
# 0.6005013623978201
# VADER
# -----
# positive correct
# 0.704925893635571
# negative correct
# 0.3659908436886854
# total
# 0.5354768392370572
# SO-CAL
# -----
# positive correct
# 0.8216652136006974
# negative correct
# 0.4293873991715718
# total
# 0.6255476839237057
# Subjectivity
# -----
# positive correct
# 0.7469485614646905
# negative correct
# 0.4391105297580118
# total
# 0.5930463215258855

# %% [markdown]
# #### 1.7
# rubric={reasoning:1}
#
# Discuss your results from 1.5 and 1.6. What stands out?

# %% [markdown]
# Answer:

# %% [markdown]
# #### 1.8 optional
# rubric={accuracy:1}
#
# Investigate these dictionaries further. Here are some questions you can try to answer: To what extent do these dictionaries contain the same words? Is there any clear patterns in the words they don't share? For the words they do share, do they always agree on the polarity? If not, why not? For the dictionaries with strength/intensity scores, how well are the intensity scores correlated? Is there any benefit to be gained from combining dictionaries, in terms of performance on the sentiment analysis task?
#
# Provide both code and discussion.

# %%
# Open-ended, no official solution!

# %% [markdown]
# ### Exercise 2: Induced lexicons

# %% [markdown]
# #### 2.1
# rubric={accuracy:2}
#
# SentiWordNet provides a positive, negative, and neutral score for each synset in WordNet, based on a random walk algorithm. Create a lexicon where the SO value for each word is the average of the positive score minus the negative score across all possible senses of each word. Do this using the words in SO-CAL, skipping words that aren't in WordNet. The [WordNet howto](https://www.nltk.org/howto/wordnet.html) and [SentiWordNet howto](http://www.nltk.org/howto/sentiwordnet.html) might be useful.

# %% [markdown]
# *good*:
#
# ```
# <good.n.01: PosScore=0.5 NegScore=0.0>          : 0.5 - 0.0
# <good.n.02: PosScore=0.875 NegScore=0.0>        : 0.875 - 0.0
# <good.n.03: PosScore=0.625 NegScore=0.0>        : ...
# <commodity.n.01: PosScore=0.0 NegScore=0.0>
# <good.a.01: PosScore=0.75 NegScore=0.0>
# <full.s.06: PosScore=0.0 NegScore=0.0>
# <good.a.03: PosScore=1.0 NegScore=0.0>
# <estimable.s.02: PosScore=1.0 NegScore=0.0>
# <beneficial.s.01: PosScore=0.625 NegScore=0.0>
# ...
# <good.s.17: PosScore=0.75 NegScore=0.0>
# <good.s.18: PosScore=0.875 NegScore=0.0>
# <good.s.19: PosScore=0.5 NegScore=0.0>
# <good.s.20: PosScore=0.375 NegScore=0.125>
# <good.s.21: PosScore=0.75 NegScore=0.0>
# <well.r.01: PosScore=0.375 NegScore=0.0>
# <thoroughly.r.02: PosScore=0.0 NegScore=0.0>
#
# sum of (positive score - negative score) / len(synsets)
# ```

# %%
SWN_lexicon = {}

def get_synset_SO(synset_name):
    '''get the SO for a synset in sentiwordnet by subtracting the neg_score from the pos_score'''
    #Your code here
    #Your code here
    
for word in SO_CAL_lexicon:
#     #Your code here
#     #Your code here

# %%
assert 0.56 <SWN_lexicon["good"] < 0.57
assert -0.60 <SWN_lexicon["bad"] < -0.59
print("Success!")
# Out:
# Success!

# %% [markdown]
# #### 2.2
# rubric={accuracy:2,efficiency:1}
#
# Given seeds provided below, build a sentiment lexicon from the word2vec vectors included in NLTK using the Semantic Axis method discussed in [25.4.1 of the J&M textbook](https://web.stanford.edu/~jurafsky/slp3/25.pdf). That is, you should calculate the centroid of the embeddings of the positive and negative seeds, create an axis by taking their difference, and then do cosine similarity of each word with that axis.

# %%
#provided code
positive_seeds = ["good", "excellent", "nice", "happy","exciting"]
negative_seeds = ["bad","poor","terrible","dull","unhappy"]

word2vec_sample = str(find('models/word2vec_sample/pruned.word2vec.txt'))
word2vec_model = gensim.models.KeyedVectors.load_word2vec_format(word2vec_sample, binary=False) # 300D

# %% [markdown]
# ```
# # use `np.sum`:
# pos_vec = word2vec_model["good"] + word2vec_model["excellent"] +  ...
# neg_vec = word2vec_model["bad"] + word2vec_model["poor"] +  ...
#
# axis_vec = pos_vec - neg_vec
#
# similarities = 1 - word2vec_model.distances(axis_vec)
# ...
#
# ```

# %%
axis_lexicon = {}

#Your code here
#Your code here

# after getting pos_vec and neg_vec, obtain axis_vec
# then, obtain smilarities 

# `awesome` where i = 22758 in word2vec_model.index_to_key[i] 
# print(similarities[22758]) --> 0.3929876
# print(word2vec_model.index_to_key[22758]) --> `awesome`
# axis_lexicon["awesome"] = 0.3929876

# %%
axis_lexicon["awesome"]
# Out:
# 0.3929876

# %%
assert 0.39 <axis_lexicon["awesome"] < 0.40
assert -0.24 > axis_lexicon["bitter"] > -0.25
print("Success!")
# Out:
# Success!

# %% [markdown]
# #### 2.3 Optional
# rubric={accuracy:1}
#
# Now we will build a lexicon using a variation of the random walk/label propogration method described in [J&M 25.4.2, p.8-9](https://web.stanford.edu/~jurafsky/slp3/25.pdf). The algorithm works as follows:
#
# 1. Create a transition matrix (between nodes in the graph) using by normalizing the cosine similarities of the word2vec vectors into a probability distribution. Only the closest 50 neighbors are preserved, and so we make use of a sparse matrix. Code that does this is provided to you, it will take a little while to run
# 2. For each of the polarities, we do a random walk by iteratively multiplying the transition matrix by a vector corresponding to the probability of visiting each node from the seeds. That vector begins with its probability mass evenly distributed across the seeds, everything else is zero.
# 3. After each step of the "walk", some of the probability mass that has been distributed needs to be given back to the seeds. This is done by setting the probability of each seed to its original value (1/number of seeds) and then renormalizing to create a probability distribution
# 4. This should be done 200 times for each of the positive and negative seeds.
# 5. A final score for each word is derived by subtracting its positive score from its negative score

# %%
#provided code
#this code builds the transition matrix. Do not modify! In addition to the transitions, you will
#want to use the word2index and index2word dictionaries

# NOTE: it takes ~3min to run;;; 

k= 50

word2index = {}

for i, word in enumerate(word2vec_model.index_to_key):
    word2index[word] = i # obtain indices of each word in the model

transitions = lil_matrix((len(word2index),len(word2index))) # create a transition matrix

for i,word in enumerate(word2vec_model.index_to_key):
    if i % 10000 ==0:
        print(i)
    nearest_neighbors = word2vec_model.most_similar(word,topn=k) # grab the k nearest neighbours
    for neighbor,similarity in nearest_neighbors:
        transitions[i,word2index[neighbor]] = similarity # create an edge weighted by the similarity

transitions = csr_matrix(transitions.multiply(1/np.sum(transitions,axis=1))) 
# normalize similarities to create probabilities
# Out:
# 0
# 10000
# 20000
# 30000
# 40000

# %%
# your `transitions` is <43981x43981 sparse matrix of type '<class 'numpy.float64'>'
#   43981 = len(word2vec_model.index_to_key)

# %%
def random_walk(transitions, seeds,iterations=200):
    
    '''carry out a random walk graph defined by transitions, starting with probability distribution
    distributed to words in seeds, and redistributed back to seeds in each iteration'''
    #Your code here
    # 1. create `output` with  `np.zeros`, and output.size = len(word2vec_model.index_to_key)
    # 2. initialize output for each seed word: output['seed_word'] = 1/len(seeds)
    # 3. iteration 1..200:
    #   output = transitions*output
    #   iterate for all seeds
    #       again, output['seed_word'] = 1/len(seeds)
    #   normalize output
    # 4. return output. 

    #Your code here

pos_seeds = [word2index[word] for word in positive_seeds]
neg_seeds = [word2index[word] for word in negative_seeds]

pos_values = random_walk(transitions,pos_seeds)
neg_values = random_walk(transitions,neg_seeds)

random_walk_lexicon = {}
diff = pos_values - neg_values
for i in range(len(pos_values)):
    random_walk_lexicon[word2vec_model.index_to_key[i]] = diff[i]

# %% [markdown]
# #### 2.4
# rubric={accuracy:1,quality:1}
#
# Finally, you will carry out an intrinsic evaluation of these lexicons, by comparing them to **a gold standard lexicon, the SO-CAL**. You first need to **create a test set which is the intersection of the keys of the SO-CAL, SWN, and Axis lexicons**. Then, for each of the induced lexicons, calculate the percentage of the test words that have the same polarity in the SO-CAL (you should ignore intensity for this).

# %%
def intrinsic_evaluate(test_set,proposed_lexicon,gold_lexicon):
    '''calculate and return percentage of words in test_set which have same polarity in 
    proposed_lexicon and gold_lexicon'''
    #Your code here
    
    #Your code here
test_set = set(SO_CAL_lexicon) & set(SWN_lexicon) & set(axis_lexicon)
print("SWN")
print(intrinsic_evaluate(test_set,SWN_lexicon,SO_CAL_lexicon)) 
print("Axis lexicon")
print(intrinsic_evaluate(test_set,axis_lexicon,SO_CAL_lexicon))
# print("Random Walk")
# print(intrinsic_evaluate(test_set,random_walk_lexicon,SO_CAL_lexicon)) #
# Out:
# SWN
# 0.6712057439960386
# Axis lexicon
# 0.8450111413716267
# Random Walk
# 0.8625897499381034

# %% [markdown]
# ### Exercise 3: Valence shifters
#
# SO-CAL has also has a dictionary of intensifiers (`int_dictionary`). The code below will load them into a dictionary where (true) intensifiers like "very" will have values greater than one and downplayers like "sorta" will have values less than one; you can multiply these modifiers by the SO scores to get the intended valence shifting effect.

# %% [markdown]
# You need to add 1 to satisfy the condition for values where they are greater and less than one:
# ```
# very	0.2     > 1           -->  0.2+1 > 1
# ...
# sorta	-0.3   < 1           --> -0.3+1 < 1
# ```

# %%
#provided code
SO_CAL_int = {}

location = "https://raw.githubusercontent.com/sfu-discourse-lab/SO-CAL/master/Resources/dictionaries/English/"
f = urllib.request.urlopen(location + "int_dictionary1.11.txt")
for line in f:
    line = line.decode("latin-1")
    if line.strip() \
        and "_" not in line: # to ignore the line with more than one words: eg. the_least	-3
        word, intensity = line.strip().split()
        SO_CAL_int[word] = float(intensity) + 1
        
print(SO_CAL_int)
# Out:
# {'less': -0.5, 'barely': -0.5, 'hardly': -0.5, 'almost': -0.5, 'only': 0.5, 'slightly': 0.5, 'marginally': 0.5, 'relatively': 0.7, 'mildly': 0.7, 'moderately': 0.7, 'somewhat': 0.7, 'partially': 0.7, 'arguably': 0.8, 'mostly': 0.8, 'mainly': 0.8, 'sorta': 0.7, 'kinda': 0.7, 'fairly': 0.8, 'pretty': 0.9, 'rather': 0.9, 'immediately': 1.1, 'quite': 1.1, 'perfectly': 1.1, 'consistently': 1.1, 'really': 1.2, 'clearly': 1.2, 'obviously': 1.2, 'certainly': 1.2, 'completely': 1.2, 'definitely': 1.2, 'absolutely': 1.2, 'constantly': 1.2, 'highly': 1.2, 'very': 1.2, 'significantly': 1.2, 'noticeably': 1.2, 'distinctively': 1.2, 'frequently': 1.2, 'awfully': 1.2, 'totally': 1.2, 'largely': 1.2, 'fully': 1.2, 'extra': 1.3, 'truly': 1.3, 'especially': 1.3, 'particularly': 1.3, 'damn': 1.3, 'intensively': 1.3, 'downright': 1.3, 'entirely': 1.3, 'strongly': 1.3, 'remarkably': 1.3, 'majorly': 1.3, 'amazingly': 1.3, 'strikingly': 1.3, 'stunningly': 1.3, 'quintessentially': 1.3, 'unusually': 1.3, 'dramatically': 1.3, 'intensely': 1.3, 'extremely': 1.4, 'so': 1.4, 'incredibly': 1.4, 'terribly': 1.4, 'hugely': 1.4, 'immensely': 1.4, 'such': 1.4, 'unbelievably': 1.4, 'insanely': 1.4, 'outrageously': 1.4, 'radically': 1.4, 'blisteringly': 1.4, 'exceptionally': 1.4, 'exceedingly': 1.4, 'way': 1.4, 'vastly': 1.4, 'deeply': 1.4, 'super': 1.4, 'profoundly': 1.4, 'universally': 1.4, 'abundantly': 1.4, 'infinitely': 1.4, 'exponentially': 1.4, 'enormously': 1.4, 'thoroughly': 1.4, 'passionately': 1.4, 'tremendously': 1.4, 'ridiculously': 1.4, 'obscenely': 1.4, 'wildly': 1.4, 'extraordinarily': 1.5, 'spectacularly': 1.5, 'phenomenally': 1.5, 'monumentally': 1.5, 'mind-bogglingly': 1.5, 'utterly': 1.5, 'more': 0.5, 'utmost': 2.0, 'total': 1.5, 'monumental': 1.5, 'great': 1.5, 'huge': 1.5, 'tremendous': 1.5, 'massive': 1.5, 'complete': 1.4, 'infinite': 1.4, 'endless': 1.4, 'absolute': 1.5, 'resounding': 1.4, 'unabashed': 1.4, 'collossal': 1.5, 'incredible': 1.5, 'unimaginable': 1.5, 'abject': 1.5, 'utter': 1.4, 'double': 1.3, 'clear': 1.3, 'clearer': 1.2, 'clearest': 1.5, 'big': 1.3, 'bigger': 1.2, 'biggest': 1.5, 'obvious': 1.03, 'serious': 1.3, 'deep': 1.3, 'deeper': 1.2, 'deepest': 1.5, 'considerable': 1.2, 'important': 1.3, 'major': 1.2, 'crucial': 1.3, 'immediate': 1.1, 'visable': 1.1, 'noticeable': 1.1, 'consistent': 1.1, 'high': 1.2, 'higher': 1.1, 'highest': 1.5, 'real': 1.2, 'true': 1.2, 'pure': 1.2, 'definite': 1.2, 'much': 1.2, 'small': 0.7, 'smaller': 0.8, 'smallest': 0.5, 'minor': 0.7, 'moderate': 0.7, 'mild': 0.7, 'slight': 0.5, 'slightest': 0.09999999999999998, 'insignificant': 0.5, 'inconsequential': 0.5, 'low': -1.0, 'lower': -0.5, 'lowest': -2.0, 'few': -1.0, 'fewer': -0.5, 'fewest': -2.0, 'numerous': 1.3, 'several': 1.2, 'multiple': 1.2, 'various': 1.2, 'heckuva': 1.5, 'some': 0.8}

# %%
print("very", SO_CAL_int["very"])
print("sorta", SO_CAL_int["sorta"])
# Out:
# very 1.2
# sorta 0.7

# %% [markdown]
# #### 3.1
# rubric={accuracy:3,quality:1}
#
# Add simple valence shifting to your SO calcuation code from 1.6. For each word, look at the previous word. If it is an intensifier/downplayer, scale up the SO value of the word according to the value in the intensifier dictionary, by multiplying. If it is the word "not" or "no", shift the SO by subtracting 4 from positive words, and adding 4 to negative words. You should implement this is in a way such that it is possible to independently test the effects of intensification and negation, as well as do both together. You can make changes to your code in 1.6 for the purposes of avoiding major duplication (though make sure you don't break anything!), but the code that carries out the valence shifting  should be in the code block below, even if some duplication of code is required.

# %% [markdown]
# -  For each word, look at the previous word. If it is an intensifier/downplayer, scale up the SO value of the word according to the value in the intensifier dictionary:  `SO *= SO_CAL_int[prev_word]`
# - If it is the word "not" or "no", shift the SO by subtracting 4 from positive words, and adding 4 to negative words: `SO += 4` or ` -= 4`

# %%
negatives = {"no","not"}

def calculate_SO(text,lexicon,ints=None, negs=None,verbose=False):
    '''calculate a semantic orientation for a text as the sum of the semantic orientation
    of the words of the text as provided by lexicon, modified by the effect of intensifiers
    if ints is True, and negators if negs is true. Returns the SO unless verbose is True,
    at which point it returns both the SO and a list of tuples correspond to each SO-bearing
    word and the SO calculated for that word'''
    #Your code here
    #Your code here

# %% [markdown]
# #### 3.2
#
# rubric={accuracy:1}
#
# Using the SO-CAL lexicon, evaluate the effect of intensification, negation, and the combination of the two valence shifters together, using the two corpora we used in Exercise 1. (You should see a consistent, though small, improvement)

# %% [markdown]
# ```
#     print("no valence shifters")
#     evaluate(...)
#     print("intensification")
#     evaluate(...)
#     print("negation")
#     evaluate(...)
#     print("both intensification and negation")
#     evaluate(...)
# ```

# %%
lexicon = SO_CAL_lexicon

for ev_name,corpus in [("Sentence Polarity",sentence_polarity),
                        ("Pros and Cons",pros_cons)]:
    print("******")
    #Your code here
    #Your code here
# Out:
# ******
# Sentence Polarity
# no valence shifters
# -----
# positive correct
# 0.7454511348715063
# negative correct
# 0.4558244231851435
# total
# 0.6006377790283249
# -------------------------
# intensification
# -----
# positive correct
# 0.7492027762145939
# negative correct
# 0.46782967548302384
# total
# 0.6085162258488088
# -------------------------
# negation
# -----
# positive correct
# 0.7447008066028887
# negative correct
# 0.45920090039392236
# total
# 0.6019508534984056
# -------------------------
# both intensification and negation
# -----
# positive correct
# 0.7480772838116676
# negative correct
# 0.4710185706246483
# total
# 0.609547927218158
# -------------------------
# ******
# Pros and Cons
# no valence shifters
# -----
# positive correct
# 0.8216652136006974
# negative correct
# 0.4293873991715718
# total
# 0.6255476839237057
# -------------------------
# intensification
# -----
# positive correct
# 0.8256756756756757
# negative correct
# 0.43514279485502505
# total
# 0.6304305177111716
# -------------------------
# negation
# -----
# positive correct
# 0.8231909328683522
# negative correct
# 0.45201656856333117
# total
# 0.6376239782016349
# -------------------------
# both intensification and negation
# -----
# positive correct
# 0.8272013949433304
# negative correct
# 0.45724874645737956
# total
# 0.6422452316076295
# -------------------------

# %% [markdown]
# ### Exercise 4: Error Analysis

# %% [markdown]
# #### 4.1
#
# rubric={accuracy:2}
#
# Adapt your earlier code such that so that it optionally keeps track of information that will help you to do an error analysis. You can add this to the earlier cell, no need to duplicate your code here. In particular, you will want to remember words which were found in the lexicon for that sentence, and their corresponding SO *after* valence shifting.
#
# Then, with this feature turned on, (1) **iterate over all the *negative* sentences** in one of the two corpora we have been using in this lab (you can choose which), and (2) **print out sentences which are not labeled as negative** by your system, along with the words in the lexicon (and their SO), as mentioned above. That is, for one incorrect sentence, your output should look something like this.
#
# - iterate `sentence_polarity.sents(categories="neg")`
# - print out not labeled as negative `calculate_SO(sent,lexicon,ints=ints,negs=negs,verbose=True) >= 0` ...

# %% [raw]
# ['on', 'its', 'own', ',', "it's", 'not', 'very', 'interesting', '.', 'as', 'a', 'remake', ',', "it's", 'a', 'pale', 'imitation', '.']
# [('interesting', 3.6), ('pale', -1.0)]

# %%
def sentence_polarity_error_analysis(lexicon,ints=None,negs=None):
    '''iterate over negative sentences in sentence polarity corpus and print out those which
    are incorrect according to SO calculated using lexicon, along with the SO calculation details'''

    #Your code here
    #Your code here       
            
sentence_polarity_error_analysis(SO_CAL_lexicon,ints=SO_CAL_int,negs=negatives)
# Out:
# ["it's", 'so', 'laddish', 'and', 'juvenile', ',', 'only', 'teenage', 'boys', 'could', 'possibly', 'find', 'it', 'funny', '.']
# [('juvenile', -2.0), ('funny', 3.0)]
# 1.0
# ['a', 'visually', 'flashy', 'but', 'narratively', 'opaque', 'and', 'emotionally', 'vapid', 'exercise', 'in', 'style', 'and', 'mystification', '.']
# [('flashy', 1.0), ('emotionally', -1.0)]
# 0.0
# ['the', 'story', 'is', 'also', 'as', 'unoriginal', 'as', 'they', 'come', ',', 'already', 'having', 'been', 'recycled', 'more', 'times', 'than', "i'd", 'care', 'to', 'count', '.']
# [('unoriginal', -2.0), ('care', 2.0)]
# 0.0
# ['a', 'sentimental', 'mess', 'that', 'never', 'rings', 'true', '.']
# [('sentimental', 2.0), ('mess', -2.0)]
# 0.0
# ['while', 'the', 'performances', 'are', 'often', 'engaging', ',', 'this', 'loose', 'collection', 'of', 'largely', 'improvised', 'numbers', 'would', 'probably', 'have', 'worked', 'better', 'as', 'a', 'one-hour', 'tv', 'documentary', '.']
# [('engaging', 4.0), ('loose', -1.0), ('better', 2.0)]
# 5.0
# ['interesting', ',', 'but', 'not', 'compelling', '.']
# [('interesting', 3.0), ('compelling', 0.0)]
# 3.0
# ['while', 'the', 'ensemble', 'player', 'who', 'gained', 'notice', 'in', 'guy', "ritchie's", 'lock', ',', 'stock', 'and', 'two', 'smoking', 'barrels', 'and', 'snatch', 'has', 'the', 'bod', ',', "he's", 'unlikely', 'to', 'become', 'a', 'household', 'name', 'on', 'the', 'basis', 'of', 'his', 'first', 'starring', 'vehicle', '.']
# [('snatch', -1.0), ('first', 1.0)]
# 0.0
# ['there', 'is', 'a', 'difference', 'between', 'movies', 'with', 'the', 'courage', 'to', 'go', 'over', 'the', 'top', 'and', 'movies', 'that', "don't", 'care', 'about', 'being', 'stupid']
# [('courage', 2.0), ('top', 2.0), ('care', 2.0), ('stupid', -4.0)]
# 2.0
# ['nothing', 'here', 'seems', 'as', 'funny', 'as', 'it', 'did', 'in', 'analyze', 'this', ',', 'not', 'even', 'joe', 'viterelli', 'as', 'de', "niro's", 'right-hand', 'goombah', '.']
# [('funny', 3.0)]
# 3.0
# ['such', 'master', 'screenwriting', 'comes', 'courtesy', 'of', 'john', 'pogue', ',', 'the', 'yale', 'grad', 'who', 'previously', 'gave', 'us', '"', 'the', 'skulls', '"', 'and', 'last', "year's", '"', 'rollerball', '.', '"', 'enough', 'said', ',', 'except', ':', 'film', 'overboard', '!']
# [('master', 2.8), ('courtesy', 1.0), ('last', 1.0), ('enough', 1.0)]
# 5.8
# ['here', ',', 'common', 'sense', 'flies', 'out', 'the', 'window', ',', 'along', 'with', 'the', 'hail', 'of', 'bullets', ',', 'none', 'of', 'which', 'ever', 'seem', 'to', 'hit', 'sascha', '.']
# [('hit', 2.0)]
# 2.0
# ['this', '100-minute', 'movie', 'only', 'has', 'about', '25', 'minutes', 'of', 'decent', 'material', '.']
# [('decent', 1.0)]
# 1.0
# ['the', 'execution', 'is', 'so', 'pedestrian', 'that', 'the', 'most', 'positive', 'comment', 'we', 'can', 'make', 'is', 'that', 'rob', 'schneider', 'actually', 'turns', 'in', 'a', 'pretty', 'convincing', 'performance', 'as', 'a', 'prissy', 'teenage', 'girl', '.']
# [('pedestrian', -2.8), ('positive', 2.0), ('rob', -2.0), ('pretty', 2.0), ('convincing', 1.8)]
# 1.0000000000000002
# ['on', 'its', 'own', ',', "it's", 'not', 'very', 'interesting', '.', 'as', 'a', 'remake', ',', "it's", 'a', 'pale', 'imitation', '.']
# [('interesting', 3.5999999999999996), ('pale', -1.0)]
# 2.5999999999999996
# ['as', 'exciting', 'as', 'all', 'this', 'exoticism', 'might', 'sound', 'to', 'the', 'typical', 'pax', 'viewer', ',', 'the', 'rest', 'of', 'us', 'will', 'be', 'lulled', 'into', 'a', 'coma', '.']
# [('exciting', 5.0), ('sound', 1.0), ('typical', 1.0)]
# 7.0
# ['our', 'culture', 'is', 'headed', 'down', 'the', 'toilet', 'with', 'the', 'ferocity', 'of', 'a', 'frozen', 'burrito', 'after', 'an', 'all-night', 'tequila', 'bender', '\x97', 'and', 'i', 'know', 'this', 'because', "i've", 'seen', "'jackass", ':', 'the', 'movie', '.', "'"]
# [('culture', 1.0), ('ferocity', -1.0)]
# 0.0
# ['the', "movie's", 'something-borrowed', 'construction', 'feels', 'less', 'the', 'product', 'of', 'loving', ',', 'well', 'integrated', 'homage', 'and', 'more', 'like', 'a', 'mere', 'excuse', 'for', 'the', 'wan', ',', 'thinly', 'sketched', 'story', '.', 'killing', 'time', ',', "that's", 'all', "that's", 'going', 'on', 'here', '.']
# [('loving', 2.0), ('well', 1.0), ('homage', 1.0), ('like', 0.5), ('mere', -2.0), ('excuse', -1.0)]
# 1.5
# ['somewhere', 'in', 'the', 'middle', ',', 'the', 'film', 'compels', ',', 'as', 'demme', 'experiments', 'he', 'harvests', 'a', 'few', 'movie', 'moment', 'gems', ',', 'but', 'the', 'field', 'of', 'roughage', 'dominates', '.']
# []
# 0
# ['the', 'action', 'clichés', 'just', 'pile', 'up', '.']
# [('action', 1.0), ('just', 1.0)]
# 2.0
# ['the', 'only', 'surprise', 'is', 'that', 'heavyweights', 'joel', 'silver', 'and', 'robert', 'zemeckis', 'agreed', 'to', 'produce', 'this', ';', 'i', 'assume', 'the', 'director', 'has', 'pictures', 'of', 'them', 'cavorting', 'in', "ladies'", 'underwear', '.']
# [('silver', 1.0)]
# 1.0
# ['i', "didn't", 'laugh', '.', 'i', "didn't", 'smile', '.', 'i', 'survived', '.']
# [('laugh', 2.0), ('smile', 1.0)]
# 3.0
# ['please', ',', 'someone', ',', 'stop', 'eric', 'schaeffer', 'before', 'he', 'makes', 'another', 'film', '.']
# [('please', 2.0)]
# 2.0
# ['.', '.', '.', 'if', "you're", 'just', 'in', 'the', 'mood', 'for', 'a', 'fun', '--', 'but', 'bad', '--', 'movie', ',', 'you', 'might', 'want', 'to', 'catch', 'freaks', 'as', 'a', 'matinee', '.']
# [('just', 1.0), ('fun', 3.0), ('bad', -3.0), ('catch', -1.0)]
# 0.0
# ['curling', 'may', 'be', 'a', 'unique', 'sport', 'but', 'men', 'with', 'brooms', 'is', 'distinctly', 'ordinary', '.']
# [('unique', 3.0), ('distinctly', 1.0)]
# 4.0
# ['though', 'the', 'opera', 'itself', 'takes', 'place', 'mostly', 'indoors', ',', 'jacquot', 'seems', 'unsure', 'of', 'how', 'to', 'evoke', 'any', 'sort', 'of', 'naturalism', 'on', 'the', 'set', '.']
# [('unsure', -1.0), ('evoke', 2.0)]
# 1.0
# ['with', 'flashbulb', 'editing', 'as', 'cover', 'for', 'the', 'absence', 'of', 'narrative', 'continuity', ',', 'undisputed', 'is', 'nearly', 'incoherent', ',', 'an', 'excuse', 'to', 'get', 'to', 'the', 'closing', 'bout', '.', '.', '.', 'by', 'which', 'time', "it's", 'impossible', 'to', 'care', 'who', 'wins', '.']
# [('continuity', 2.0), ('excuse', -1.0), ('bout', -1.0), ('impossible', -1.0), ('care', 2.0)]
# 1.0
# ['equlibrium', 'could', 'pass', 'for', 'a', "thirteen-year-old's", 'book', 'report', 'on', 'the', 'totalitarian', 'themes', 'of', '1984', 'and', 'farenheit', '451', '.']
# []
# 0
# ['the', 'lack', 'of', 'naturalness', 'makes', 'everything', 'seem', 'self-consciously', 'poetic', 'and', 'forced', '.', '.', '.', "it's", 'a', 'pity', 'that', "[nelson's]", 'achievement', "doesn't", 'match', 'his', 'ambition', '.']
# [('lack', -2.0), ('poetic', 3.0), ('pity', -1.0), ('achievement', 3.0)]
# 3.0
# ['everything', 'is', 'off', '.']
# []
# 0
# ['when', 'seagal', 'appeared', 'in', 'an', 'orange', 'prison', 'jumpsuit', ',', 'i', 'wanted', 'to', 'stand', 'up', 'in', 'the', 'theater', 'and', 'shout', ',', "'hey", ',', 'kool-aid', '!', "'"]
# []
# 0
# ['imagine', 'the', 'cleanflicks', 'version', 'of', "'love", 'story', ',', "'", 'with', 'ali', "macgraw's", 'profanities', 'replaced', 'by', 'romance-novel', 'platitudes', '.']
# []
# 0
# ['pc', 'stability', 'notwithstanding', ',', 'the', 'film', 'suffers', 'from', 'a', 'simplistic', 'narrative', 'and', 'a', 'pat', ',', 'fairy-tale', 'conclusion', '.']
# [('stability', 1.0), ('simplistic', -1.0)]
# 0.0
# ['though', 'her', 'fans', 'will', 'assuredly', 'have', 'their', 'funny', 'bones', 'tickled', ',', 'others', 'will', 'find', 'their', 'humor-seeking', 'dollars', 'best', 'spent', 'elsewhere', '.']
# [('funny', 3.0), ('best', 5.0)]
# 8.0
# ['a', 'static', 'and', 'sugary', 'little', 'half-hour', ',', 'after-school', 'special', 'about', 'interfaith', 'understanding', ',', 'stretched', 'out', 'to', '90', 'minutes', '.']
# [('static', -1.0), ('little', -1.0), ('special', 3.0), ('understanding', 1.0)]
# 2.0
# ['watching', 'the', 'chemistry', 'between', 'freeman', 'and', 'judd', ',', 'however', ',', 'almost', 'makes', 'this', 'movie', 'worth', 'seeing', '.', 'almost', '.']
# [('worth', 2.0)]
# 2.0
# ['only', 'in', 'its', 'final', 'surprising', 'shots', 'does', 'rabbit-proof', 'fence', 'find', 'the', 'authority', "it's", 'looking', 'for', '.']
# []
# 0
# ["isn't", 'as', 'sharp', 'as', 'the', 'original', '.', '.', '.', 'despite', 'some', 'visual', 'virtues', ',', "'blade", "ii'", 'just', "doesn't", 'cut', 'it', '.']
# [('sharp', 1.0), ('original', 1.0), ('just', 1.0)]
# 3.0
# ['.', '.', '.', 'plays', 'like', 'a', 'badly', 'edited', ',', '91-minute', 'trailer', '(', 'and', ')', 'the', 'director', "can't", 'seem', 'to', 'get', 'a', 'coherent', 'rhythm', 'going', '.', 'in', 'fact', ',', 'it', "doesn't", 'even', 'seem', 'like', 'she', 'tried', '.']
# [('like', 1.0), ('badly', -3.0), ('coherent', 2.0), ('like', 1.0)]
# 1.0
# ['what', 'you', 'expect', 'is', 'just', 'what', 'you', 'get', '.', '.', '.', 'assuming', 'the', 'bar', 'of', 'expectations', "hasn't", 'been', 'raised', 'above', 'sixth-grade', 'height', '.']
# [('just', 1.0)]
# 1.0
# ['barry', 'sonnenfeld', 'owes', 'frank', 'the', 'pug', 'big', 'time']
# [('big', 1.0)]
# 1.0
# ['so', 'riddled', 'with', 'unanswered', 'questions', 'that', 'it', 'requires', 'gargantuan', 'leaps', 'of', 'faith', 'just', 'to', 'watch', 'it', 'plod', 'along', '.']
# [('faith', 2.0), ('just', 1.0), ('plod', -1.0)]
# 2.0
# ['i', 'approached', 'the', 'usher', 'and', 'said', 'that', 'if', 'she', 'had', 'to', 'sit', 'through', 'it', 'again', ',', 'she', 'should', 'ask', 'for', 'a', 'raise', '.']
# []
# 0
# ['a', 'punch', 'line', 'without', 'a', 'premise', ',', 'a', 'joke', 'built', 'entirely', 'from', 'musty', 'memories', 'of', 'half-dimensional', 'characters', '.']
# [('joke', 1.0)]
# 1.0
# ['takes', 'one', 'character', 'we', "don't", 'like', 'and', 'another', 'we', "don't", 'believe', ',', 'and', 'puts', 'them', 'into', 'a', 'battle', 'of', 'wills', 'that', 'is', 'impossible', 'to', 'care', 'about', 'and', "isn't", 'very', 'funny', '.']
# [('like', 1.0), ('battle', -1.0), ('impossible', -1.0), ('care', 2.0), ('funny', 3.5999999999999996)]
# 4.6
# ['the', 'things', 'this', 'movie', 'tries', 'to', 'get', 'the', 'audience', 'to', 'buy', 'just', "won't", 'fly', 'with', 'most', 'intelligent', 'viewers', '.']
# [('just', 1.0), ('intelligent', 4.0)]
# 5.0
# ['sitting', 'through', 'the', 'last', 'reel', '(', 'spoiler', 'alert', '!', ')', 'is', 'significantly', 'less', 'charming', 'than', 'listening', 'to', 'a', 'four-year-old', 'with', 'a', 'taste', 'for', 'exaggeration', 'recount', 'his', 'halloween', 'trip', 'to', 'the', 'haunted', 'house', '.']
# [('last', 1.0), ('significantly', 1.0), ('charming', -2.0), ('taste', 2.0), ('exaggeration', -2.0)]
# 0.0
# ['confuses', 'its', 'message', 'with', 'an', 'ultimate', 'desire', 'to', 'please', ',', 'and', 'contorting', 'itself', 'into', 'an', 'idea', 'of', 'expectation', 'is', 'the', 'last', 'thing', 'any', 'of', 'these', 'three', 'actresses', ',', 'nor', 'their', 'characters', ',', 'deserve', '.']
# [('ultimate', 1.0), ('please', 2.0), ('last', 1.0), ('deserve', 2.0)]
# 6.0
# ['with', 'this', 'new', 'rollerball', ',', 'sense', 'and', 'sensibility', 'have', 'been', 'overrun', 'by', 'what', 'can', 'only', 'be', 'characterized', 'as', 'robotic', 'sentiment', '.']
# [('new', 2.0), ('overrun', -1.0)]
# 1.0
# ['one', 'can', 'only', 'assume', 'that', 'the', 'jury', 'who', 'bestowed', 'star', "hoffman's", 'brother', 'gordy', 'with', 'the', 'waldo', 'salt', 'screenwriting', 'award', 'at', "2002's", 'sundance', 'festival', 'were', 'honoring', 'an', 'attempt', 'to', 'do', 'something', 'different', 'over', 'actually', 'pulling', 'it', 'off']
# [('award', 1.0), ('attempt', -1.0)]
# 0.0
# ['the', 'script', 'covers', 'huge', ',', 'heavy', 'topics', 'in', 'a', 'bland', ',', 'surfacey', 'way', 'that', "doesn't", 'offer', 'any', 'insight', 'into', 'why', ',', 'for', 'instance', ',', 'good', 'things', 'happen', 'to', 'bad', 'people', '.']
# [('huge', 1.0), ('heavy', -1.0), ('bland', -2.0), ('offer', 1.0), ('insight', 3.0), ('good', 3.0), ('bad', -3.0)]
# 2.0
# ['a', 'portrait', 'of', 'alienation', 'so', 'perfect', ',', 'it', 'will', 'certainly', 'succeed', 'in', 'alienating', 'most', 'viewers', '.']
# [('alienation', -1.0), ('perfect', 7.0), ('succeed', 3.5999999999999996)]
# 9.6
# ['the', 'code', 'talkers', 'deserved', 'better', 'than', 'a', 'hollow', 'tribute', '.']
# [('deserved', 1.0), ('better', 2.0), ('hollow', -2.0), ('tribute', 1.0)]
# 2.0
# ['skip', 'the', 'film', 'and', 'buy', 'the', 'philip', 'glass', 'soundtrack', 'cd', '.']
# []
# 0
# ['dignified', "ceo's", 'meet', 'at', 'a', 'rustic', 'retreat', 'and', 'pee', 'against', 'a', 'tree', '.', 'can', 'you', 'bear', 'the', 'laughter', '?']
# [('dignified', 2.0), ('rustic', 1.0), ('retreat', -1.0), ('bear', -1.0), ('laughter', 1.0)]
# 2.0
# ['beware', 'the', 'quirky', 'brit-com', '.', 'they', 'can', 'and', 'will', 'turn', 'on', 'a', 'dime', 'from', 'oddly', 'humorous', 'to', 'tediously', 'sentimental', '.']
# [('beware', -2.0), ('quirky', 1.0), ('oddly', -1.0), ('humorous', 3.0), ('tediously', -3.0), ('sentimental', 2.0)]
# 0.0
# ['has', 'its', 'moments', '--', 'and', 'almost', 'as', 'many', 'subplots', '.']
# []
# 0
# ['the', 'gags', ',', 'and', 'the', 'script', ',', 'are', 'a', 'mixed', 'bag', '.']
# []
# 0
# ['adam', "sandler's", 'heart', 'may', 'be', 'in', 'the', 'right', 'place', ',', 'but', 'he', 'needs', 'to', 'pull', 'his', 'head', 'out', 'of', 'his', 'butt']
# [('heart', 1.0), ('right', 1.0)]
# 2.0
# ['despite', 'engaging', 'offbeat', 'touches', ',', 'knockaround', 'guys', 'rarely', 'seems', 'interested', 'in', 'kicking', 'around', 'a', 'raison', "d'etre", "that's", 'as', 'fresh-faced', 'as', 'its', 'young-guns', 'cast', '.']
# [('engaging', 4.0), ('offbeat', 1.0), ('rarely', -1.0)]
# 4.0
# ['some', 'episodes', 'work', ',', 'some', "don't", '.']
# []
# 0
# ['beautifully', 'filmed', 'and', 'well', 'acted', '.', '.', '.', 'but', 'admittedly', 'problematic', 'in', 'its', 'narrative', 'specifics', '.']
# [('beautifully', 4.0), ('well', 1.0), ('problematic', -3.0)]
# 2.0
# ['j', '.', 'lo', 'will', 'earn', 'her', 'share', 'of', 'the', 'holiday', 'box', 'office', 'pie', ',', 'although', 'this', 'movie', 'makes', 'one', 'thing', 'perfectly', 'clear', ':', "she's", 'a', 'pretty', 'woman', ',', 'but', "she's", 'no', 'working', 'girl', '.']
# [('earn', 1.0), ('share', 1.0), ('perfectly', 5.0), ('clear', 2.2), ('pretty', 2.0)]
# 11.2
# ['rymer', "doesn't", 'trust', 'laughs', '--', 'and', "doesn't", 'conjure', 'proper', 'respect', 'for', 'followers', 'of', 'the', 'whole', 'dead-undead', 'genre', ',', 'who', 'deserve', 'more', 'from', 'a', 'vampire', 'pic', 'than', 'a', 'few', 'shrieky', 'special', 'effects', '.']
# [('trust', 2.0), ('proper', 1.0), ('respect', 3.0), ('deserve', 2.0), ('special', 3.0)]
# 11.0
# ['wow', '.', 'i', 'have', 'not', 'been', 'this', 'disappointed', 'by', 'a', 'movie', 'in', 'a', 'long', 'time', '.']
# [('wow', 3.0), ('long', -1.0)]
# 2.0
# ['off', 'the', 'hook', 'is', 'overlong', 'and', 'not', 'well-acted', ',', 'but', 'credit', 'writer-producer-director', 'adam', 'watstein', 'with', 'finishing', 'it', 'at', 'all', '.']
# [('well-acted', 0.0), ('credit', 2.0)]
# 2.0
# ["it's", 'also', 'curious', 'to', 'note', 'that', 'this', 'film', ',', 'like', 'the', 'similarly', 'ill-timed', 'antitrust', ',', 'is', 'easily', 'as', 'bad', 'at', 'a', 'fraction', 'the', 'budget', '.']
# [('like', 1.0), ('easily', 3.0), ('bad', -3.0)]
# 1.0
# ["there's", 'nothing', 'interesting', 'in', 'unfaithful', 'whatsoever', '.']
# [('interesting', 3.0), ('unfaithful', -2.0)]
# 1.0
# ['none', 'of', 'this', 'is', 'half', 'as', 'moving', 'as', 'the', 'filmmakers', 'seem', 'to', 'think', '.']
# [('moving', 3.0)]
# 3.0
# ['a', 'processed', 'comedy', 'chop', 'suey', '.']
# [('comedy', 1.0)]
# 1.0
# ['as', 'spent', 'screen', 'series', 'go', ',', 'star', 'trek', ':', 'nemesis', 'is', 'even', 'more', 'suggestive', 'of', 'a', '65th', 'class', 'reunion', 'mixer', 'where', 'only', 'eight', 'surviving', 'members', 'show', 'up', '--', 'and', "there's", 'nothing', 'to', 'drink', '.']
# [('reunion', 2.0)]
# 2.0
# ['full', 'of', 'the', 'kind', 'of', 'obnoxious', 'chitchat', 'that', 'only', 'self-aware', 'neurotics', 'engage', 'in', '.']
# [('kind', 2.0), ('obnoxious', -3.0), ('engage', 2.0)]
# 1.0
# ['an', 'erotic', 'thriller', "that's", 'neither', 'too', 'erotic', 'nor', 'very', 'thrilling', ',', 'either', '.']
# [('erotic', 2.0), ('too', -3.0), ('erotic', 2.0), ('thrilling', 3.5999999999999996)]
# 4.6
# ['the', 'movie', ',', 'like', 'bartleby', ',', 'is', 'something', 'of', 'a', 'stiff', '--', 'an', 'extra-dry', 'office', 'comedy', 'that', 'seems', 'twice', 'as', 'long', 'as', 'its', '83', 'minutes', '.']
# [('like', 1.0), ('stiff', -1.0), ('comedy', 1.0), ('long', -1.0)]
# 0.0
# ['the', 'director', 'and', 'her', 'capable', 'cast', 'appear', 'to', 'be', 'caught', 'in', 'a', 'heady', 'whirl', 'of', 'new', 'age-inspired', 'good', 'intentions', ',', 'but', 'the', 'spell', 'they', 'cast', "isn't", 'the', 'least', 'bit', 'mesmerizing', '.']
# [('capable', 2.0), ('new', 2.0), ('good', 3.0), ('spell', 1.0), ('mesmerizing', 4.0)]
# 12.0
# ['everything', 'is', 'pegged', 'into', 'the', 'groove', 'of', 'a', 'new', 'york', 'dating', 'comedy', 'with', "'issues'", 'to', 'simplify', '.']
# [('new', 2.0), ('comedy', 1.0), ('simplify', 1.0)]
# 4.0
# ['a', 'dramatic', 'comedy', 'as', 'pleasantly', 'dishonest', 'and', 'pat', 'as', 'any', 'hollywood', 'fluff', '.']
# [('dramatic', 1.0), ('comedy', 1.0), ('pleasantly', 3.0), ('dishonest', -3.0), ('fluff', -2.0)]
# 0.0
# ['the', 'cameo-packed', ',', 'm', ':', 'i-2-spoofing', 'title', 'sequence', 'is', 'the', 'funniest', '5', 'minutes', 'to', 'date', 'in', 'this', 'spy', 'comedy', 'franchise', '.', '.', '.', 'then', 'mike', 'myers', 'shows', 'up', 'and', 'ruins', 'everything', '.']
# [('comedy', 1.0)]
# 1.0
# ['so', 'genial', 'is', 'the', 'conceit', ',', 'this', 'is', 'one', 'of', 'those', 'rare', 'pictures', 'that', 'you', 'root', 'for', 'throughout', ',', 'dearly', 'hoping', 'that', 'the', 'rich', 'promise', 'of', 'the', 'script', 'will', 'be', 'realized', 'on', 'the', 'screen', '.', 'it', 'never', 'is', ',', 'not', 'fully', '.']
# [('conceit', -2.0), ('rare', 1.0), ('dearly', 3.0), ('rich', 3.0), ('promise', 2.0)]
# 7.0
# ['even', 'in', 'the', 'summertime', ',', 'the', 'most', 'restless', 'young', 'audience', 'deserves', 'the', 'dignity', 'of', 'an', 'action', 'hero', 'motivated', 'by', 'something', 'more', 'than', 'franchise', 'possibilities', '.']
# [('restless', -1.0), ('young', 1.0), ('dignity', 2.0), ('action', 1.0), ('hero', 2.0)]
# 5.0
# ['what', 'with', 'all', 'the', 'blanket', 'statements', 'and', 'dime-store', 'ruminations', 'on', 'vanity', ',', 'the', 'worries', 'of', 'the', 'rich', 'and', 'sudden', 'wisdom', ',', 'the', 'film', 'becomes', 'a', 'sermon', 'for', 'most', 'of', 'its', 'running', 'time', '.']
# [('rich', 3.0), ('wisdom', 3.0)]
# 6.0
# ['the', 'four', 'feathers', 'is', 'definitely', 'horse', 'feathers', ',', 'but', 'if', 'you', 'go', 'in', 'knowing', 'that', ',', 'you', 'might', 'have', 'fun', 'in', 'this', 'cinematic', 'sandbox', '.']
# [('fun', 3.0)]
# 3.0
# ['solaris', '"', 'is', 'a', 'shapeless', 'inconsequential', 'move', 'relying', 'on', 'the', 'viewer', 'to', 'do', 'most', 'of', 'the', 'work', '.']
# []
# 0
# ['though', 'this', 'saga', 'would', 'be', 'terrific', 'to', 'read', 'about', ',', 'it', 'is', 'dicey', 'screen', 'material', 'that', 'only', 'a', 'genius', 'should', 'touch', '.']
# [('terrific', 5.0), ('genius', 4.0)]
# 9.0
# ['it', 'has', 'plenty', 'of', 'laughs', '.', 'it', 'just', "doesn't", 'have', 'much', 'else', '.', '.', '.', 'especially', 'in', 'a', 'moral', 'sense', '.']
# [('just', 1.0), ('moral', 2.0)]
# 3.0
# ['it', 'may', 'play', 'well', 'as', 'a', 'double', 'feature', 'with', 'mainstream', 'foreign', 'mush', 'like', 'my', 'big', 'fat', 'greek', 'wedding']
# [('well', 1.0), ('feature', 2.6), ('foreign', -1.0), ('like', 1.0), ('big', 1.0), ('fat', -3.9000000000000004)]
# 0.6999999999999993
# ['by', 'the', 'time', 'you', 'reach', 'the', 'finale', ',', "you're", 'likely', 'wondering', 'why', "you've", 'been', 'watching', 'all', 'this', 'strutting', 'and', 'posturing', '.']
# []
# 0
# ['at', 'its', 'best', ',', "it's", 'black', 'hawk', 'down', 'with', 'more', 'heart', '.', 'at', 'its', 'worst', ',', "it's", 'rambo-', 'meets-john', 'ford', '.']
# [('best', 5.0), ('heart', 0.5), ('worst', -5.0)]
# 0.5
# ['exactly', 'what', "you'd", 'expect', 'from', 'a', 'guy', 'named', 'kaos', '.']
# []
# 0
# ['this', 'movie', '.', '.', '.', "doesn't", 'deserve', 'the', 'energy', 'it', 'takes', 'to', 'describe', 'how', 'bad', 'it', 'is', '.']
# [('deserve', 2.0), ('energy', 1.0), ('bad', -3.0)]
# 0.0
# ['with', 'or', 'without', 'ballast', 'tanks', ',', 'k-19', 'sinks', 'to', 'a', 'harrison', 'ford', 'low', '.']
# []
# 0
# ['director', 'oliver', 'parker', 'labors', 'so', 'hard', 'to', 'whip', 'life', 'into', 'the', 'importance', 'of', 'being', 'earnest', 'that', 'he', 'probably', 'pulled', 'a', 'muscle', 'or', 'two', '.']
# [('hard', -1.4), ('whip', -1.0), ('importance', 2.0), ('earnest', 2.0)]
# 1.6
# ["it's", 'not', 'nearly', 'as', 'fresh', 'or', 'enjoyable', 'as', 'its', 'predecessor', ',', 'but', 'there', 'are', 'enough', 'high', 'points', 'to', 'keep', 'this', 'from', 'being', 'a', 'complete', 'waste', 'of', 'time', '.']
# [('fresh', 2.0), ('enjoyable', 4.0), ('enough', 1.0), ('complete', 1.0), ('waste', -2.8)]
# 5.2
# ['walsh', "can't", 'quite', 'negotiate', 'the', 'many', 'inconsistencies', 'in', "janice's", 'behavior', 'or', 'compensate', 'for', 'them', 'by', 'sheer', 'force', 'of', 'charm', '.']
# [('compensate', 1.0), ('force', -2.0), ('charm', 2.0)]
# 1.0
# ['this', '10th', 'film', 'in', 'the', 'series', 'looks', 'and', 'feels', 'tired', '.']
# []
# 0
# ['it', 'leers', ',', 'offering', 'next', 'to', 'little', 'insight', 'into', 'its', 'intriguing', 'subject', '.']
# [('little', -1.0), ('insight', 3.0), ('intriguing', 3.0), ('subject', -1.0)]
# 4.0
# ["there's", 'nothing', 'to', 'gain', 'from', 'watching', 'they', '.', 'it', "isn't", 'scary', '.', 'it', 'hates', 'its', 'characters', '.', 'it', 'finds', 'no', 'way', 'to', 'entertain', 'or', 'inspire', 'its', 'viewers', '.']
# [('gain', 2.0), ('scary', -3.0), ('entertain', 3.0), ('inspire', 2.0)]
# 4.0
# ['fear', 'permeates', 'the', 'whole', 'of', 'stortelling', ',', 'todd', "solondz'", 'oftentimes', 'funny', ',', 'yet', 'ultimately', 'cowardly', 'autocritique', '.']
# [('fear', -2.0), ('funny', 3.0)]
# 1.0
# ['the', 'skirmishes', 'for', 'power', 'waged', 'among', 'victims', 'and', 'predators', 'settle', 'into', 'an', 'undistinguished', 'rhythm', 'of', 'artificial', 'suspense', '.']
# [('power', 1.0), ('artificial', -1.0)]
# 0.0
# ['.', '.', '.', 'ice', 'age', 'treads', 'predictably', 'along', 'familiar', 'territory', ',', 'making', 'it', 'a', 'passable', 'family', 'film', 'that', "won't", 'win', 'many', 'fans', 'over', 'the', 'age', 'of', '12', '.']
# [('predictably', -2.0), ('familiar', 1.0), ('win', 2.0)]
# 1.0
# ['though', 'the', 'film', 'is', 'well-intentioned', ',', 'one', 'could', 'rent', 'the', 'original', 'and', 'get', 'the', 'same', 'love', 'story', 'and', 'parable', '.']
# [('well-intentioned', 2.0), ('original', 1.0), ('love', 3.0)]
# 6.0
# ['a', 'cleverly', 'crafted', 'but', 'ultimately', 'hollow', 'mockumentary', '.']
# [('cleverly', 3.0), ('hollow', -2.0)]
# 1.0
# ['it', 'gets', 'bogged', 'down', 'by', 'hit-and-miss', 'topical', 'humour', 'before', 'getting', 'to', 'the', 'truly', 'good', 'stuff', '.']
# [('humour', 1.0), ('good', 3.9000000000000004)]
# 4.9
# ['an', 'achingly', 'enthralling', 'premise', ',', 'the', 'film', 'is', 'hindered', 'by', 'uneven', 'dialogue', 'and', 'plot', 'lapses', '.']
# [('enthralling', 4.0), ('uneven', -1.0)]
# 3.0
# ['if', 'you', 'go', 'into', 'the', 'theater', 'expecting', 'a', 'scary', ',', 'action-packed', 'chiller', ',', 'you', 'might', 'soon', 'be', 'looking', 'for', 'a', 'sign', '.', 'an', 'exit', 'sign', ',', 'that', 'is', '.']
# [('scary', -3.0), ('action-packed', 3.0)]
# 0.0
# ['what', 'you', 'end', 'up', 'getting', 'is', 'the', 'vertical', 'limit', 'of', 'surfing', 'movies', '-', 'memorable', 'stunts', 'with', 'lots', 'of', 'downtime', 'in', 'between', '.']
# [('memorable', 3.0)]
# 3.0
# ['stealing', 'harvard', "doesn't", 'care', 'about', 'cleverness', ',', 'wit', 'or', 'any', 'other', 'kind', 'of', 'intelligent', 'humor', '.']
# [('care', 2.0), ('wit', 2.0), ('kind', 2.0), ('intelligent', 4.0), ('humor', 2.0)]
# 12.0
# ["there's", 'undeniable', 'enjoyment', 'to', 'be', 'had', 'from', 'films', 'crammed', 'with', 'movie', 'references', ',', 'but', 'the', 'fun', 'wears', 'thin', '--', 'then', 'out', '--', 'when', "there's", 'nothing', 'else', 'happening', '.']
# [('enjoyment', 3.0), ('fun', 3.0)]
# 6.0
# ['the', 'film', 'favors', 'the', 'scientific', 'over', 'the', 'spectacular', '(', 'visually', 'speaking', ')', '.']
# [('scientific', 1.0), ('spectacular', 5.0)]
# 6.0
# ['with', 'the', 'exception', 'of', 'mccoist', ',', 'the', 'players', "don't", 'have', 'a', 'clue', 'on', 'the', 'park', '.', 'the', 'acting', "isn't", 'much', 'better', '.']
# [('better', 2.4)]
# 2.4
# ['a', 'suffocating', 'rape-payback', 'horror', 'show', 'that', 'hinges', 'on', 'the', "subgenre's", 'most', 'enabling', 'victim', '.', '.', '.', 'and', 'an', 'ebullient', 'affection', 'for', 'industrial-model', 'meat', 'freezers', '.']
# [('horror', -2.0), ('victim', -2.0), ('ebullient', 4.0), ('affection', 3.0)]
# 3.0
# ['star', 'trek', 'was', 'kind', 'of', 'terrific', 'once', ',', 'but', 'now', 'it', 'is', 'a', 'copy', 'of', 'a', 'copy', 'of', 'a', 'copy', '.']
# [('kind', 2.0), ('terrific', 5.0)]
# 7.0
# ['[n]o', 'matter', 'how', 'much', 'good', 'will', 'the', 'actors', 'generate', ',', 'showtime', 'eventually', 'folds', 'under', 'its', 'own', 'thinness', '.']
# [('good', 3.5999999999999996), ('generate', 1.0)]
# 4.6
# ['every', 'potential', 'twist', 'is', 'telegraphed', 'well', 'in', 'advance', ',', 'every', 'performance', 'respectably', 'muted', ';', 'the', 'movie', 'itself', 'seems', 'to', 'have', 'been', 'made', 'under', 'the', 'influence', 'of', 'rohypnol', '.']
# [('well', 1.0)]
# 1.0
# ['puts', 'on', 'airs', 'of', 'a', 'hal', 'hartley', 'wannabe', 'film', '--', 'without', 'the', 'vital', 'comic', 'ingredient', 'of', 'the', 'hilarious', 'writer-director', 'himself', '.']
# [('wannabe', -3.0), ('vital', 1.0), ('comic', 1.0), ('hilarious', 4.0)]
# 3.0
# ['despite', 'a', 'performance', 'of', 'sustained', 'intelligence', 'from', 'stanford', 'and', 'another', 'of', 'subtle', 'humour', 'from', 'bebe', 'neuwirth', ',', 'as', 'an', 'older', 'woman', 'who', 'seduces', 'oscar', ',', 'the', 'film', 'founders', 'on', 'its', 'lack', 'of', 'empathy', 'for', 'the', 'social', 'milieu', '-', 'rich', 'new', 'york', 'intelligentsia', '-', 'and', 'its', 'off']
# [('intelligence', 3.0), ('subtle', 1.0), ('humour', 1.0), ('lack', -2.0), ('empathy', 2.0), ('social', 1.0), ('rich', 3.0), ('new', 2.0)]
# 11.0
# ['although', 'disney', 'follows', 'its', 'standard', 'formula', 'in', 'this', 'animated', 'adventure', ',', 'it', 'feels', 'more', 'forced', 'than', 'usual', '.']
# [('standard', 1.0), ('adventure', 2.0), ('usual', 1.0)]
# 4.0
# ['gaghan', '.', '.', '.', 'has', 'thrown', 'every', 'suspenseful', 'cliché', 'in', 'the', 'book', 'at', 'this', 'nonsensical', 'story', '.']
# [('suspenseful', 2.0), ('nonsensical', -2.0)]
# 0.0
# ["'you'll", 'laugh', 'for', 'not', 'quite', 'and', 'hour', 'and', 'a', 'half', ',', 'but', 'come', 'out', 'feeling', 'strangely', 'unsatisfied', '.', "you'll", 'feel', 'like', 'you', 'ate', 'a', 'reeses', 'without', 'the', 'peanut', 'butter', '.', '.', '.', "'"]
# [('laugh', 2.0), ('strangely', -1.0), ('like', 1.0)]
# 2.0
# ['gooding', 'offers', 'a', 'desperately', 'ingratiating', 'performance', '.']
# [('desperately', -2.0), ('ingratiating', 2.0)]
# 0.0
# ['parker', 'should', 'be', 'commended', 'for', 'taking', 'a', 'fresh', 'approach', 'to', 'familiar', 'material', ',', 'but', 'his', 'determination', 'to', 'remain', 'true', 'to', 'the', 'original', 'text', 'leads', 'him', 'to', 'adopt', 'a', 'somewhat', 'mannered', 'tone', '.', '.', '.', 'that', 'ultimately', 'dulls', 'the', 'human', 'tragedy', 'at', 'the', "story's", 'core', '.']
# [('fresh', 2.0), ('familiar', 1.0), ('determination', 1.0), ('original', 1.0), ('human', 2.0), ('tragedy', -3.0)]
# 4.0
# ['the', 'director', 'has', 'injected', 'self-consciousness', 'into', 'the', 'proceedings', 'at', 'every', 'turn', '.', 'the', 'results', 'are', 'far', 'more', 'alienating', 'than', 'involving', '.']
# []
# 0
# ['a', 'lack', 'of', 'thesis', 'makes', 'maryam', ',', 'in', 'the', 'end', ',', 'play', 'out', 'with', 'the', 'intellectual', 'and', 'emotional', 'impact', 'of', 'an', 'after-school', 'special', '.']
# [('lack', -2.0), ('intellectual', 3.0), ('emotional', -1.0), ('impact', 1.0), ('special', 3.0)]
# 4.0
# ['by-the-numbers', 'yarn', '.']
# []
# 0
# ['if', 'h', '.', 'g', '.', 'wells', 'had', 'a', 'time', 'machine', 'and', 'could', 'take', 'a', 'look', 'at', 'his', "kin's", 'reworked', 'version', ',', 'what', 'would', 'he', 'say', '?', "'it", 'looks', 'good', ',', 'sonny', ',', 'but', 'you', 'missed', 'the', 'point', '.', "'"]
# [('good', 3.0)]
# 3.0
# ['during', 'the', "tuxedo's", '90', 'minutes', 'of', 'screen', 'time', ',', 'there', "isn't", 'one', 'true', "'chan", "moment'", '.']
# []
# 0
# ['watching', 'austin', 'powers', 'in', 'goldmember', 'is', 'like', 'binging', 'on', 'cotton', 'candy', '.', "it's", 'sweet', 'and', 'fluffy', 'at', 'the', 'time', ',', 'but', 'it', 'may', 'leave', 'you', 'feeling', 'a', 'little', 'sticky', 'and', 'unsatisfied', '.']
# [('like', 1.0), ('sweet', 3.0), ('fluffy', -1.0), ('little', -1.0), ('sticky', -1.0)]
# 1.0
# ['the', 'most', 'anti-human', 'big', 'studio', 'picture', 'since', '3000', 'miles', 'to', 'graceland', '.']
# [('big', 1.0)]
# 1.0
# ["i'm", 'sure', 'the', 'filmmakers', 'found', 'this', 'a', 'remarkable', 'and', 'novel', 'concept', ',', 'but', 'anybody', 'who', 'has', 'ever', 'seen', 'an', 'independent', 'film', 'can', 'report', 'that', 'it', 'is', 'instead', 'a', 'cheap', 'cliché', '.']
# [('sure', 1.0), ('remarkable', 4.0), ('novel', 1.0), ('independent', 1.0), ('cheap', -1.0)]
# 6.0
# ['the', 'acting', 'is', 'fine', 'but', 'the', 'script', 'is', 'about', 'as', 'interesting', 'as', 'a', 'recording', 'of', 'conversations', 'at', 'the', 'wal-mart', 'checkout', 'line', '.']
# [('fine', 2.0), ('interesting', 3.0)]
# 5.0
# ['the', 'plot', 'plummets', 'into', 'a', 'comedy', 'graveyard', 'before', 'janice', 'comes', 'racing', 'to', 'the', 'rescue', 'in', 'the', 'final', 'reel', '.']
# [('comedy', 1.0), ('rescue', 1.0)]
# 2.0
# ['sometimes', 'there', 'are', 'very', ',', 'very', 'good', 'reasons', 'for', 'certain', 'movies', 'to', 'be', 'sealed', 'in', 'a', 'jar', 'and', 'left', 'on', 'a', 'remote', 'shelf', 'indefinitely', '.']
# [('good', 3.5999999999999996), ('remote', -1.0)]
# 2.5999999999999996
# ["here's", 'my', 'advice', ',', 'kev', '.', 'start', 'reading', 'your', 'scripts', 'before', 'signing', 'that', 'dotted', 'line', '.']
# []
# 0
# ['an', 'alternately', 'raucous', 'and', 'sappy', 'ethnic', 'sitcom', '.', '.', '.', "you'd", 'be', 'wise', 'to', 'send', 'your', 'regrets', '.']
# [('sappy', -2.0), ('wise', 3.0)]
# 1.0
# ['unfortunately', ',', "it's", 'also', 'not', 'very', 'good', '.', 'especially', 'compared', 'with', 'the', 'television', 'series', 'that', 'inspired', 'the', 'movie', '.']
# [('unfortunately', -2.0), ('good', 3.5999999999999996)]
# 1.5999999999999996
# ['it', 'wraps', 'up', 'a', 'classic', 'mother/daughter', 'struggle', 'in', 'recycled', 'paper', 'with', 'a', 'shiny', 'new', 'bow', 'and', 'while', 'the', 'audience', 'can', 'tell', "it's", 'not', 'all', 'new', ',', 'at', 'least', 'it', 'looks', 'pretty', '.']
# [('classic', 4.0), ('struggle', -2.0), ('shiny', 1.0), ('new', 2.0), ('new', 2.0), ('pretty', 2.0)]
# 9.0
# ['this', 'is', 'the', 'kind', 'of', 'movie', 'during', 'which', 'you', 'want', 'to', 'bang', 'your', 'head', 'on', 'the', 'seat', 'in', 'front', 'of', 'you', ',', 'at', 'its', 'cluelessness', ',', 'at', 'its', 'idiocy', ',', 'at', 'its', 'utterly', 'misplaced', 'earnestness', '.']
# [('kind', 2.0), ('earnestness', 2.0)]
# 4.0
# ['it', 'winds', 'up', 'moving', 'in', 'many', 'directions', 'as', 'it', 'searches', '(', 'vainly', ',', 'i', 'think', ')', 'for', 'something', 'fresh', 'to', 'say', '.']
# [('moving', 3.0), ('vainly', -2.0), ('fresh', 2.0)]
# 3.0
# ['all', 'in', 'all', ',', 'road', 'to', 'perdition', 'is', 'more', 'in', 'love', 'with', 'strangeness', 'than', 'excellence', '.']
# [('love', 3.0), ('strangeness', -1.0), ('excellence', 4.0)]
# 6.0
# ['a', 'mimetic', 'approximation', 'of', 'better', 'films', 'like', 'contempt', 'and', '8', '1/2', '.']
# [('better', 2.0), ('like', 1.0), ('contempt', -3.0)]
# 0.0
# ['watching', 'the', 'powerpuff', 'girls', 'movie', ',', 'my', 'mind', 'kept', 'returning', 'to', 'one', 'anecdote', 'for', 'comparison', ':', 'the', 'cartoon', 'in', 'japan', 'that', 'gave', 'people', 'seizures', '.']
# []
# 0
# ['aan', 'opportunity', 'wasted', '.']
# [('opportunity', 1.0)]
# 1.0
# ['an', 'inelegant', 'combination', 'of', 'two', 'unrelated', 'shorts', 'that', 'falls', 'far', 'short', 'of', 'the', "director's", 'previous', 'work', 'in', 'terms', 'of', 'both', 'thematic', 'content', 'and', 'narrative', 'strength', '.']
# [('inelegant', -1.0), ('short', -1.0), ('content', 1.0), ('strength', 2.0)]
# 1.0
# ['although', 'it', 'tries', 'to', 'be', 'much', 'more', ',', "it's", 'really', 'just', 'another', 'major', 'league', '.']
# [('just', 1.2)]
# 1.2
# ['one', 'thing', 'is', 'for', 'sure', ':', 'this', 'movie', 'does', 'not', 'tell', 'you', 'a', 'whole', 'lot', 'about', 'lily', 'chou-chou', '.']
# [('sure', 1.0)]
# 1.0
# ['with', 'a', 'tone', 'as', 'variable', 'as', 'the', 'cinematography', ',', "schaeffer's", 'film', 'never', 'settles', 'into', 'the', 'light-footed', 'enchantment', 'the', 'material', 'needs', ',', 'and', 'the', "characters'", 'quirks', 'and', 'foibles', 'never', 'jell', 'into', 'charm', '.']
# [('variable', -1.0), ('enchantment', 3.0), ('charm', 2.0)]
# 4.0
# ['to', 'better', 'understand', 'why', 'this', "didn't", 'connect', 'with', 'me', 'would', 'require', 'another', 'viewing', ',', 'and', 'i', "won't", 'be', 'sitting', 'through', 'this', 'one', 'again', '.', '.', '.', 'that', 'in', 'itself', 'is', 'commentary', 'enough', '.']
# [('better', 2.0), ('enough', 1.0)]
# 3.0
# ['cuba', 'gooding', 'jr', '.', 'valiantly', 'mugs', 'his', 'way', 'through', 'snow', 'dogs', ',', 'but', 'even', 'his', 'boisterous', 'energy', 'fails', 'to', 'spark', 'this', 'leaden', 'comedy', '.']
# [('valiantly', 3.0), ('boisterous', 2.0), ('energy', 1.0), ('leaden', -2.0), ('comedy', 1.0)]
# 5.0
# ['not', 'at', 'all', 'clear', 'what', "it's", 'trying', 'to', 'say', 'and', 'even', 'if', 'it', 'were', '\x96', 'i', 'doubt', 'it', 'would', 'be', 'all', 'that', 'interesting', '.']
# [('clear', 2.0), ('doubt', -1.0), ('interesting', 3.0)]
# 4.0
# ["it's", 'like', 'an', 'all-star', 'salute', 'to', "disney's", 'cheesy', 'commercialism', '.']
# [('like', 1.0), ('all-star', 5.0), ('salute', 1.0), ('cheesy', -2.0)]
# 5.0
# ['some', 'of', 'the', 'computer', 'animation', 'is', 'handsome', ',', 'and', 'various', 'amusing', 'sidekicks', 'add', 'much-needed', 'levity', 'to', 'the', 'otherwise', 'bleak', 'tale', ',', 'but', 'overall', 'the', 'film', 'never', 'rises', 'above', 'mediocrity', '.']
# [('handsome', 4.0), ('amusing', 3.5999999999999996), ('bleak', -3.0), ('mediocrity', -2.0)]
# 2.5999999999999996
# ["there's", 'an', 'excellent', '90-minute', 'film', 'here', ';', 'unfortunately', ',', 'it', 'runs', 'for', '170', '.']
# [('excellent', 5.0), ('unfortunately', -2.0)]
# 3.0
# ['as', 'saccharine', 'movies', 'go', ',', 'this', 'is', 'likely', 'to', 'cause', 'massive', 'cardiac', 'arrest', 'if', 'taken', 'in', 'large', 'doses', '.']
# [('large', 1.0)]
# 1.0
# ['as', 'is', 'often', 'the', 'case', 'with', 'ambitious', ',', 'eager', 'first-time', 'filmmakers', ',', 'mr', '.', 'murray', ',', 'a', 'prolific', 'director', 'of', 'music', 'videos', ',', 'stuffs', 'his', 'debut', 'with', 'more', 'plot', 'than', 'it', 'can', 'comfortably', 'hold', '.']
# [('ambitious', -1.0), ('eager', 2.0), ('prolific', 3.0), ('comfortably', 2.0)]
# 6.0
# ['the', 'mystery', 'of', 'enigma', 'is', 'how', 'a', 'rich', 'historical', 'subject', ',', 'combined', 'with', 'so', 'much', 'first-rate', 'talent', '.', '.', '.', 'could', 'have', 'yielded', 'such', 'a', 'flat', ',', 'plodding', 'picture', '.']
# [('rich', 3.0), ('subject', -1.0), ('first-rate', 4.8), ('talent', 3.0), ('flat', -2.0), ('plodding', -3.0)]
# 4.800000000000001
# ['it', 'throws', 'quirky', 'characters', ',', 'odd', 'situations', ',', 'and', 'off-kilter', 'dialogue', 'at', 'us', ',', 'all', 'as', 'if', 'to', 'say', ',', '"', 'look', 'at', 'this', '!', 'this', 'is', 'an', 'interesting', 'movie', '!', '"', 'but', 'the', 'film', 'itself', 'is', 'ultimately', 'quite', 'unengaging', '.']
# [('quirky', 1.0), ('odd', -1.0), ('interesting', 3.0)]
# 3.0
# ['while', 'it', 'is', 'interesting', 'to', 'witness', 'the', 'conflict', 'from', 'the', 'palestinian', 'side', ',', "longley's", 'film', 'lacks', 'balance', '.', '.', '.', 'and', 'fails', 'to', 'put', 'the', 'struggle', 'into', 'meaningful', 'historical', 'context', '.']
# [('interesting', 3.0), ('conflict', -2.0), ('balance', 1.0), ('struggle', -2.0), ('meaningful', 3.0)]
# 3.0
# ['woo', 'has', 'as', 'much', 'right', 'to', 'make', 'a', 'huge', 'action', 'sequence', 'as', 'any', 'director', ',', 'but', 'how', 'long', 'will', 'filmmakers', 'copy', 'the', '"', 'saving', 'private', 'ryan', '"', 'battle', 'scenes', 'before', 'realizing', 'steven', 'spielberg', 'got', 'it', 'right', 'the', 'first', 'time', '?']
# [('right', 1.2), ('huge', 1.0), ('action', 1.5), ('long', -1.0), ('battle', -1.0), ('right', 1.0), ('first', 1.0)]
# 3.7
# ["it's", 'sincere', 'to', 'a', 'fault', ',', 'but', ',', 'unfortunately', ',', 'not', 'very', 'compelling', 'or', 'much', 'fun', '.']
# [('sincere', 2.0), ('fault', -2.0), ('unfortunately', -2.0), ('compelling', 4.8), ('fun', 3.5999999999999996)]
# 6.3999999999999995
# ['.', '.', '.', 'jones', ',', 'despite', 'a', 'definitely', 'distinctive', 'screen', 'presence', ',', 'just', "isn't", 'able', 'to', 'muster', 'for', 'a', 'movie', 'that', ',', 'its', 'title', 'notwithstanding', ',', 'should', 'have', 'been', 'a', 'lot', 'nastier', 'if', 'it', 'wanted', 'to', 'fully', 'capitalize', 'on', 'its', "lead's", 'specific', 'gifts', '.']
# [('distinctive', 1.2), ('just', 1.0), ('able', 1.0), ('muster', -1.0), ('capitalize', 1.2)]
# 3.4000000000000004
# ['this', 'follow-up', 'seems', 'so', 'similar', 'to', 'the', '1953', 'disney', 'classic', 'that', 'it', 'makes', 'one', 'long', 'for', 'a', 'geriatric', 'peter', '.']
# [('classic', 4.0), ('long', -1.0)]
# 3.0
# ['why', ',', 'you', 'may', 'ask', ',', 'why', 'should', 'you', 'buy', 'the', 'movie', 'milk', 'when', 'the', 'tv', 'cow', 'is', 'free', '?', "there's", 'no', 'good', 'answer', 'to', 'that', 'one', '.']
# [('free', 3.0), ('good', -1.0)]
# 2.0
# ['this', 'is', 'amusing', 'for', 'about', 'three', 'minutes', '.']
# [('amusing', 3.0)]
# 3.0
# ['klein', ',', 'charming', 'in', 'comedies', 'like', 'american', 'pie', 'and', 'dead-on', 'in', 'election', ',', 'delivers', 'one', 'of', 'the', 'saddest', 'action', 'hero', 'performances', 'ever', 'witnessed', '.']
# [('charming', 4.0), ('like', 1.0), ('action', 1.0), ('hero', 2.0)]
# 8.0
# ["it's", 'rare', 'to', 'see', 'a', 'movie', 'that', 'takes', 'such', 'a', 'speedy', 'swan', 'dive', 'from', '"', 'promising', '"', 'to', '"', 'interesting', '"', 'to', '"', 'familiar', '"', 'before', 'landing', 'squarely', 'on', '"', 'stupid', '"', '.']
# [('rare', 1.0), ('speedy', 1.0), ('promising', 2.0), ('interesting', 3.0), ('familiar', 1.0), ('stupid', -4.0)]
# 4.0
# ['the', 'direction', 'occasionally', 'rises', 'to', 'the', 'level', 'of', 'marginal', 'competence', ',', 'but', 'for', 'most', 'of', 'the', 'film', 'it', 'is', 'hard', 'to', 'tell', 'who', 'is', 'chasing', 'who', 'or', 'why', '.']
# [('marginal', -1.0), ('competence', 2.0), ('hard', -1.0)]
# 0.0
# ['there', 'are', 'few', 'things', 'more', 'frustrating', 'to', 'a', 'film', 'buff', 'than', 'seeing', 'an', 'otherwise', 'good', 'movie', 'marred', 'beyond', 'redemption', 'by', 'a', 'disastrous', 'ending', '.']
# [('frustrating', -1.0), ('buff', 3.0), ('good', 3.0), ('redemption', 2.0)]
# 7.0
# ['it', "won't", 'harm', 'anyone', ',', 'but', 'neither', 'can', 'i', 'think', 'of', 'a', 'very', 'good', 'reason', 'to', 'rush', 'right', 'out', 'and', 'see', 'it', '.', 'after', 'all', ',', "it'll", 'probably', 'be', 'in', 'video', 'stores', 'by', 'christmas', ',', 'and', 'it', 'might', 'just', 'be', 'better', 'suited', 'to', 'a', 'night', 'in', 'the', 'living', 'room', 'than', 'a', 'night', 'at', 'the', 'movies', '.']
# [('harm', -2.0), ('good', 3.5999999999999996), ('right', 1.0), ('just', 1.0), ('better', 2.0)]
# 5.6
# ['looks', 'more', 'like', 'a', 'travel-agency', 'video', 'targeted', 'at', 'people', 'who', 'like', 'to', 'ride', 'bikes', 'topless', 'and', 'roll', 'in', 'the', 'mud', 'than', 'a', 'worthwhile', 'glimpse', 'of', 'independent-community', 'guiding', 'lights', '.']
# [('like', 0.5), ('like', 1.0), ('worthwhile', 3.0)]
# 4.5
# ['they', 'kept', 'much', 'of', 'the', 'plot', 'but', 'jettisoned', 'the', 'stuff', 'that', 'would', 'make', 'this', 'a', 'moving', 'experience', 'for', 'people', 'who', "haven't", 'read', 'the', 'book', '.']
# [('moving', 3.0), ('experience', 1.0)]
# 4.0
# ['just', 'because', 'a', 'walk', 'to', 'remember', 'is', 'shrewd', 'enough', 'to', 'activate', 'girlish', 'tear', 'ducts', "doesn't", 'mean', "it's", 'good', 'enough', 'for', 'our', 'girls', '.']
# [('just', 1.0), ('shrewd', 1.0), ('enough', 1.0), ('tear', -1.0), ('good', 3.0), ('enough', 1.0)]
# 6.0
# ["[carvey's]", 'characters', 'are', 'both', 'overplayed', 'and', 'exaggerated', ',', 'but', 'then', 'again', ',', 'subtlety', 'has', 'never', 'been', 'his', 'trademark', '.']
# []
# 0
# ["brown's", 'saga', ',', 'like', 'many', 'before', 'his', ',', 'makes', 'for', 'snappy', 'prose', 'but', 'a', 'stumblebum', 'of', 'a', 'movie', '.']
# [('like', 1.0), ('snappy', 2.0)]
# 3.0
# ['the', "boys'", 'sparring', ',', 'like', 'the', 'succession', 'of', 'blows', 'dumped', 'on', 'guei', ',', 'wears', 'down', 'the', "story's", 'more', 'cerebral', ',', 'and', 'likable', ',', 'plot', 'elements', '.']
# [('like', 1.0), ('likable', 2.0)]
# 3.0
# ['the', 'story', 'is', 'so', 'light', 'and', 'sugary', 'that', 'were', 'it', 'a', "macy's", 'thanksgiving', 'day', 'parade', 'balloon', ',', 'extra', 'heavy-duty', 'ropes', 'would', 'be', 'needed', 'to', 'keep', 'it', 'from', 'floating', 'away', '.']
# [('extra', 1.0), ('heavy-duty', 2.6)]
# 3.6
# ['oedekerk', 'mugs', 'mercilessly', ',', 'and', 'the', 'genuinely', 'funny', 'jokes', 'are', 'few', 'and', 'far', 'between', '.']
# [('mercilessly', -3.0), ('genuinely', 2.0), ('funny', 3.0)]
# 2.0
# ['only', 'those', 'most', 'addicted', 'to', 'film', 'violence', 'in', 'all', 'its', 'forms', 'will', 'find', 'anything', 'here', 'to', 'appreciate', '.']
# [('violence', -2.0), ('appreciate', 2.0)]
# 0.0
# ['cold', 'and', 'scattered', ',', 'minority', 'report', 'commands', 'interest', 'almost', 'solely', 'as', 'an', 'exercise', 'in', 'gorgeous', 'visuals', '.', "that's", 'not', 'vintage', 'spielberg', 'and', 'that', ',', 'finally', ',', 'is', 'minimally', 'satisfying', '.']
# [('cold', -1.0), ('interest', 2.0), ('gorgeous', 5.0), ('minimally', -1.0), ('satisfying', 3.0)]
# 8.0
# ['the', 'trappings', 'of', 'i', 'spy', 'are', 'so', 'familiar', 'you', 'might', 'as', 'well', 'be', 'watching', 'a', 'rerun', '.']
# [('familiar', 1.4), ('well', 1.0)]
# 2.4
# ['what', 'starts', 'off', 'as', 'a', 'potentially', 'incredibly', 'twisting', 'mystery', 'becomes', 'simply', 'a', 'monster', 'chase', 'film', '.']
# [('incredibly', 5.0), ('monster', -2.0)]
# 3.0
# ['really', 'does', 'feel', 'like', 'a', 'short', 'stretched', 'out', 'to', 'feature', 'length', '.']
# [('like', 1.0), ('short', -1.0), ('feature', 2.0)]
# 2.0
# ['and', 'if', 'you', 'appreciate', 'the', 'one-sided', 'theme', 'to', "lawrence's", 'over-indulgent', 'tirade', ',', 'then', 'knock', 'yourself', 'out', 'and', 'enjoy', 'the', 'big', 'screen', 'postcard', 'that', 'is', 'a', 'self-glorified', 'martin', 'lawrence', 'lovefest', '.', 'if', 'you', 'are', 'willing', 'to', 'do', 'this', ',', 'then', 'you', 'so', 'crazy', '!']
# [('appreciate', 2.0), ('one-sided', -2.0), ('tirade', -3.0), ('enjoy', 3.0), ('big', 1.0), ('willing', 1.0), ('crazy', -1.4)]
# 0.6000000000000001
# ['directed', 'without', 'the', 'expected', 'flair', 'or', 'imagination', 'by', 'hong', 'kong', 'master', 'john', 'woo', ',', 'windtalkers', 'airs', 'just', 'about', 'every', 'cliche', 'in', 'the', 'war', 'movie', 'compendium', 'across', 'its', 'indulgent', 'two-hour-and-fifteen-minute', 'length', '.']
# [('flair', 2.0), ('imagination', 2.0), ('master', 2.0), ('just', 1.0), ('cliche', -2.0), ('war', -2.0), ('indulgent', -2.0)]
# 1.0
# ["it's", 'a', 'very', 'tasteful', 'rock', 'and', 'roll', 'movie', '.', 'you', 'could', 'put', 'it', 'on', 'a', 'coffee', 'table', 'anywhere', '.']
# [('tasteful', 1.2), ('rock', 4.0)]
# 5.2
# ['the', 'movie', 'is', 'loaded', 'with', 'good', 'intentions', ',', 'but', 'in', 'his', 'zeal', 'to', 'squeeze', 'the', 'action', 'and', 'our', 'emotions', 'into', 'the', 'all-too-familiar', 'dramatic', 'arc', 'of', 'the', 'holocaust', 'escape', 'story', ',', 'minac', 'drains', 'his', 'movie', 'of', 'all', 'individuality', '.']
# [('good', 3.0), ('action', 1.0), ('dramatic', 1.0)]
# 5.0
# ['an', 'infuriating', 'film', '.', 'just', 'when', 'you', 'think', 'you', 'are', 'making', 'sense', 'of', 'it', ',', 'something', 'happens', 'that', 'tells', 'you', 'there', 'is', 'no', 'sense', '.']
# [('just', 1.0)]
# 1.0
# ['the', 'setting', 'turns', 'out', 'to', 'be', 'more', 'interesting', 'than', 'any', 'of', 'the', 'character', 'dramas', ',', 'which', 'never', 'reach', 'satisfying', 'conclusions', '.']
# [('interesting', 1.5), ('satisfying', 3.0)]
# 4.5
# ['as', 'an', 'entertainment', 'destination', 'for', 'the', 'general', 'public', ',', 'kung', 'pow', 'sets', 'a', 'new', 'benchmark', 'for', 'lameness', '.']
# [('entertainment', 2.0), ('new', 2.0)]
# 4.0
# ['less-than-compelling', 'documentary', 'of', 'a', 'yiddish', 'theater', 'clan', '.']
# []
# 0
# ['that', 'the', 'chuck', 'norris', '"', 'grenade', 'gag', '"', 'occurs', 'about', '7', 'times', 'during', 'windtalkers', 'is', 'a', 'good', 'indication', 'of', 'how', 'serious-minded', 'the', 'film', 'is', '.']
# [('gag', 1.0), ('good', 3.0)]
# 4.0
# ['viewers', 'are', 'asked', 'so', 'often', 'to', 'suspend', 'belief', 'that', 'were', 'it', 'not', 'for', "holm's", 'performance', ',', 'the', 'film', 'would', 'be', 'a', 'total', 'washout', '.']
# []
# 0
# ["it's", 'not', 'exactly', 'worth', 'the', 'bucks', 'to', 'expend', 'the', 'full', 'price', 'for', 'a', 'date', ',', 'but', 'when', 'it', 'comes', 'out', 'on', 'video', ',', "it's", 'well', 'worth', 'a', 'rental', '.']
# [('worth', 2.0), ('well', 1.0), ('worth', 2.0)]
# 5.0
# ['i', "can't", 'begin', 'to', 'tell', 'you', 'how', 'tedious', ',', 'how', 'resolutely', 'unamusing', ',', 'how', 'thoroughly', 'unrewarding', 'all', 'of', 'this', 'is', ',', 'and', 'what', 'a', 'reckless', 'squandering', 'of', 'four', 'fine', 'acting', 'talents', '.', '.', '.']
# [('tedious', -3.0), ('unamusing', 2.0), ('thoroughly', 2.0), ('reckless', -2.0), ('fine', 2.0)]
# 1.0
# ['everybody', 'loves', 'a', 'david', 'and', 'goliath', 'story', ',', 'and', 'this', 'one', 'is', 'told', 'almost', 'entirely', 'from', "david's", 'point', 'of', 'view', '.']
# []
# 0
# ['throw', 'smoochy', 'from', 'the', 'train', '!']
# []
# 0
# ['eventually', ',', 'they', 'will', 'have', 'a', 'showdown', ',', 'but', ',', 'by', 'then', ',', 'your', 'senses', 'are', 'as', 'mushy', 'as', 'peas', 'and', 'you', "don't", 'care', 'who', 'fires', 'the', 'winning', 'shot', '.']
# [('mushy', -1.0), ('care', 2.0)]
# 1.0
# ['irwin', 'and', 'his', 'director', 'never', 'come', 'up', 'with', 'an', 'adequate', 'reason', 'why', 'we', 'should', 'pay', 'money', 'for', 'what', 'we', 'can', 'get', 'on', 'television', 'for', 'free', '.']
# [('adequate', 1.0), ('free', 3.0)]
# 4.0
# ['a', 'light', ',', 'engaging', 'comedy', 'that', 'fumbles', 'away', 'almost', 'all', 'of', 'its', 'accumulated', 'enjoyment', 'with', 'a', 'crucial', 'third', 'act', 'miscalculation', '.']
# [('engaging', 4.0), ('comedy', 1.0), ('enjoyment', 3.0), ('miscalculation', -1.0)]
# 7.0
# ['cedar', 'somewhat', 'defuses', 'this', 'provocative', 'theme', 'by', 'submerging', 'it', 'in', 'a', 'hoary', 'love', 'triangle', '.']
# [('love', 3.0)]
# 3.0
# ...
# [('joke', 1.0)]
# 1.0
# ["it's", 'really', 'just', 'another', 'silly', 'hollywood', 'action', 'film', ',', 'one', 'among', 'a', 'multitude', 'of', 'simple-minded', ',', 'yahoo-ing', 'death', 'shows', '.']
# [('just', 1.2), ('silly', -1.0), ('action', 1.0), ('multitude', 1.0), ('death', -1.0)]
# 1.2000000000000002
# ["it's", 'not', 'a', 'particularly', 'good', 'film', ',', 'but', 'neither', 'is', 'it', 'a', 'monsterous', 'one', '.']
# [('good', 3.9000000000000004)]
# 3.9000000000000004
# ['the', 'world', 'needs', 'more', 'filmmakers', 'with', 'passionate', 'enthusiasms', 'like', 'martin', 'scorsese', '.', 'but', 'it', "doesn't", 'need', 'gangs', 'of', 'new', 'york', '.']
# [('passionate', 3.0), ('like', 1.0), ('new', 2.0)]
# 6.0
# ['sade', 'achieves', 'the', 'near-impossible', ':', 'it', 'turns', 'the', 'marquis', 'de', 'sade', 'into', 'a', 'dullard', '.']
# []
# 0
# ['one', 'of', 'the', 'most', 'plain', ',', 'unimaginative', 'romantic', 'comedies', "i've", 'ever', 'seen', '.']
# [('plain', -1.0), ('unimaginative', -2.0), ('romantic', 3.0)]
# 0.0
# ['unless', 'there', 'are', 'zoning', 'ordinances', 'to', 'protect', 'your', 'community', 'from', 'the', 'dullest', 'science', 'fiction', ',', 'impostor', 'is', 'opening', 'today', 'at', 'a', 'theater', 'near', 'you', '.']
# [('protect', 1.0), ('community', 1.0)]
# 2.0
# ['it', 'should', 'be', 'doing', 'a', 'lot', 'of', 'things', ',', 'but', "doesn't", '.']
# []
# 0
# ['the', 'movie', 'tries', 'to', 'be', 'ethereal', ',', 'but', 'ends', 'up', 'seeming', 'goofy', '.']
# [('ethereal', 2.0)]
# 2.0
# ['i', 'was', 'hoping', 'that', 'it', 'would', 'be', 'sleazy', 'and', 'fun', ',', 'but', 'it', 'was', 'neither', '.']
# [('sleazy', -3.0), ('fun', 3.0)]
# 0.0
# ['rather', 'than', 'real', 'figures', ',', 'elling', 'and', 'kjell', 'bjarne', 'become', 'symbolic', 'characters', 'whose', 'actions', 'are', 'supposed', 'to', 'relate', 'something', 'about', 'the', "naïf's", 'encounter', 'with', 'the', 'world', '.']
# [('real', 1.0)]
# 1.0
# ['mariah', 'carey', 'gives', 'us', 'another', 'peek', 'at', 'some', 'of', 'the', 'magic', 'we', 'saw', 'in', 'glitter', 'here', 'in', 'wisegirls', '.']
# [('magic', 1.0), ('glitter', 1.0)]
# 2.0
# ["it's", 'all', 'arty', 'and', 'jazzy', 'and', 'people', 'sit', 'and', 'stare', 'and', 'turn', 'away', 'from', 'one', 'another', 'instead', 'of', 'talking', 'and', "it's", 'all', 'about', 'the', 'silences', 'and', 'if', "you're", 'into', 'that', ',', 'have', 'at', 'it', '.']
# [('jazzy', 1.0)]
# 1.0
# ['the', 'lead', 'actors', 'share', 'no', 'chemistry', 'or', 'engaging', 'charisma', '.', 'we', "don't", 'even', 'like', 'their', 'characters', '.']
# [('share', 1.0), ('engaging', 4.0), ('charisma', 3.0), ('like', 1.0)]
# 9.0
# ['some', 'writer', 'dude', ',', 'i', 'think', 'his', 'name', 'was', ',', 'uh', ',', 'michael', 'zaidan', ',', 'was', 'supposed', 'to', 'have', 'like', 'written', 'the', 'screenplay', 'or', 'something', ',', 'but', ',', 'dude', ',', 'the', 'only', 'thing', 'that', 'i', 'ever', 'saw', 'that', 'was', 'written', 'down', 'were', 'the', 'zeroes', 'on', 'my', 'paycheck', '.']
# [('like', 1.0)]
# 1.0
# ['this', 'feature', 'is', 'about', 'as', 'necessary', 'as', 'a', 'hole', 'in', 'the', 'head']
# [('feature', 2.0)]
# 2.0
# ['spectators', 'will', 'indeed', 'sit', 'open-mouthed', 'before', 'the', 'screen', ',', 'not', 'screaming', 'but', 'yawning', '.']
# []
# 0
# ['a', 'period', 'story', 'about', 'a', 'catholic', 'boy', 'who', 'tries', 'to', 'help', 'a', 'jewish', 'friend', 'get', 'into', 'heaven', 'by', 'sending', 'the', 'audience', 'straight', 'to', 'hell', '.']
# [('help', 1.0), ('friend', 2.0), ('heaven', 3.0), ('hell', -3.0)]
# 3.0
# ['did', 'we', 'really', 'need', 'a', 'remake', 'of', '"', 'charade', '?', '"']
# []
# 0
# ['some', 'movies', 'can', 'get', 'by', 'without', 'being', 'funny', 'simply', 'by', 'structuring', 'the', 'scenes', 'as', 'if', 'they', 'were', 'jokes', ':', 'a', 'setup', ',', 'delivery', 'and', 'payoff', '.', 'stealing', 'harvard', "can't", 'even', 'do', 'that', 'much', '.', 'each', 'scene', 'immediately', 'succumbs', 'to', 'gravity', 'and', 'plummets', 'to', 'earth', '.']
# [('funny', 3.0)]
# 3.0
# ['the', 'satire', 'is', 'just', 'too', 'easy', 'to', 'be', 'genuinely', 'satisfying', '.']
# [('just', 1.0), ('too', -3.0), ('easy', 1.0), ('genuinely', 2.0), ('satisfying', 3.0)]
# 4.0
# ['a', 'very', 'familiar', 'tale', ',', 'one', "that's", 'been', 'told', 'by', 'countless', 'filmmakers', 'about', 'italian-', ',', 'chinese-', ',', 'irish-', ',', 'latin-', ',', 'indian-', ',', 'russian-', 'and', 'other', 'hyphenate', 'american', 'young', 'men', 'struggling', 'to', 'balance', 'conflicting', 'cultural', 'messages', '.']
# [('familiar', 1.2), ('young', 1.0), ('struggling', -2.0), ('balance', 1.0)]
# 1.2000000000000002
# ['essentially', ',', 'the', 'film', 'is', 'weak', 'on', 'detail', 'and', 'strong', 'on', 'personality']
# [('weak', -2.0), ('strong', 2.0)]
# 0.0
# ['[hell', 'is]', 'looking', 'down', 'at', 'your', 'watch', 'and', 'realizing', 'serving', 'sara', "isn't", 'even', 'halfway', 'through', '.']
# []
# 0
# ['leaves', 'viewers', 'out', 'in', 'the', 'cold', 'and', 'undermines', 'some', 'phenomenal', 'performances', '.']
# [('cold', -1.0), ('phenomenal', 4.0)]
# 3.0
# ['you', 'have', 'no', 'affinity', 'for', 'most', 'of', 'the', 'characters', '.', 'nothing', 'about', 'them', 'is', 'attractive', '.', 'what', 'they', 'see', 'in', 'each', 'other', 'also', 'is', 'difficult', 'to', 'fathom', '.']
# [('attractive', 3.0), ('difficult', -2.0)]
# 1.0
# ['diaz', ',', 'applegate', ',', 'blair', 'and', 'posey', 'are', 'suitably', 'kooky', 'which', 'should', 'appeal', 'to', 'women', 'and', 'they', 'strip', 'down', 'often', 'enough', 'to', 'keep', 'men', 'alert', ',', 'if', 'not', 'amused', '.']
# [('suitably', 2.0), ('enough', 1.0)]
# 3.0
# ['a', 'technically', 'well-made', 'suspenser', '.', '.', '.', 'but', 'its', 'abrupt', 'drop', 'in', 'iq', 'points', 'as', 'it', 'races', 'to', 'the', 'finish', 'line', 'proves', 'simply', 'too', 'discouraging', 'to', 'let', 'slide', '.']
# [('well-made', 4.0), ('too', -3.0), ('discouraging', -1.0)]
# 0.0
# ["it's", 'a', 'mystery', 'how', 'the', 'movie', 'could', 'be', 'released', 'in', 'this', 'condition', '.']
# []
# 0
# ['blade', 'ii', 'has', 'a', 'brilliant', 'director', 'and', 'charismatic', 'star', ',', 'but', 'it', 'suffers', 'from', 'rampant', 'vampire', 'devaluation', '.']
# [('brilliant', 5.0), ('charismatic', 3.0), ('rampant', -1.0)]
# 7.0
# ['movies', 'like', 'high', 'crimes', 'flog', 'the', 'dead', 'horse', 'of', 'surprise', 'as', 'if', 'it', 'were', 'an', 'obligation', '.', 'how', 'about', 'surprising', 'us', 'by', 'trying', 'something', 'new', '?']
# [('like', 1.0), ('dead', -3.0), ('new', 2.0)]
# 0.0
# ['final', 'verdict', ':', "you've", 'seen', 'it', 'all', 'before', '.']
# []
# 0
# ['if', 'a', 'few', 'good', 'men', 'told', 'us', 'that', 'we', '"', "can't", 'handle', 'the', 'truth', '"', 'than', 'high', 'crimes', 'poetically', 'states', 'at', 'one', 'point', 'in', 'this', 'movie', 'that', 'we', '"', "don't", 'care', 'about', 'the', 'truth', '.', '"']
# [('good', -3.0), ('truth', 1.0), ('care', 2.0), ('truth', 1.0)]
# 1.0
# ['the', 'movie', 'is', 'a', 'little', 'tired', ';', 'maybe', 'the', 'original', 'inspiration', 'has', 'run', 'its', 'course', '.']
# [('little', -1.0), ('original', 1.0), ('inspiration', 3.0)]
# 3.0
# ["it's", 'a', 'big', 'idea', ',', 'but', 'the', 'film', 'itself', 'is', 'small', 'and', 'shriveled', '.']
# [('big', 1.0), ('small', -1.0)]
# 0.0
# ['the', 'cast', 'has', 'a', 'high', 'time', ',', 'but', 'de', 'broca', 'has', 'little', 'enthusiasm', 'for', 'such', 'antique', 'pulp', '.']
# [('little', -1.0), ('enthusiasm', 2.0), ('antique', 1.4)]
# 2.4
# ['the', 'film', 'has', 'too', 'many', 'spots', 'where', "it's", 'on', 'slippery', 'footing', ',', 'but', 'is', 'acceptable', 'entertainment', 'for', 'the', 'entire', 'family', 'and', 'one', "that's", 'especially', 'fit', 'for', 'the', 'kiddies', '.']
# [('too', -3.0), ('slippery', -1.0), ('acceptable', 1.0), ('entertainment', 2.0), ('fit', 2.6)]
# 1.6
# ['purports', 'to', 'be', 'a', 'hollywood', 'satire', 'but', 'winds', 'up', 'as', 'the', 'kind', 'of', 'film', 'that', 'should', 'be', 'the', 'target', 'of', 'something', 'deeper', 'and', 'more', 'engaging', '.', 'oh', ',', 'and', 'more', 'entertaining', ',', 'too', '.']
# [('kind', 2.0), ('engaging', 2.0), ('entertaining', 1.0), ('too', -3.0)]
# 2.0
# ['though', 'it', 'was', 'made', 'with', 'careful', 'attention', 'to', 'detail', 'and', 'is', 'well-acted', 'by', 'james', 'spader', 'and', 'maggie', 'gyllenhaal', ',', 'i', 'felt', 'disrespected', '.']
# [('careful', 1.0), ('well-acted', 4.0)]
# 5.0
# ['well-made', 'but', 'mush-hearted', '.']
# [('well-made', 4.0)]
# 4.0
# ['a', 'real', 'snooze', '.']
# [('real', 1.0)]
# 1.0
# ['skillful', 'as', 'he', 'is', ',', 'mr', '.', 'shyamalan', 'is', 'undone', 'by', 'his', 'pretensions', '.']
# [('skillful', 2.0), ('undone', -2.0)]
# 0.0
# ['while', 'the', 'new', 'film', 'is', 'much', 'more', 'eye-catching', 'than', 'its', 'blood-drenched', 'stephen', 'norrington-directed', 'predecessor', ',', 'the', 'new', 'script', 'by', 'the', 'returning', 'david', 's', '.', 'goyer', 'is', 'much', 'sillier', '.']
# [('new', 2.0), ('new', 2.0)]
# 4.0
# ['it', 'shares', 'the', 'first', 'two', "films'", 'loose-jointed', 'structure', ',', 'but', 'laugh-out-loud', 'bits', 'are', 'few', 'and', 'far', 'between', '.']
# [('first', 1.0), ('laugh-out-loud', 3.0)]
# 4.0
# ['barney', 'throws', 'away', 'the', 'goodwill', 'the', 'first', 'half', 'of', 'his', 'movie', 'generates', 'by', 'orchestrating', 'a', 'finale', 'that', 'is', 'impenetrable', 'and', 'dull', '.']
# [('goodwill', 2.0), ('first', 1.0), ('impenetrable', 1.0), ('dull', -2.0)]
# 2.0
# ['if', "you're", 'really', 'renting', 'this', "you're", 'not', 'interested', 'in', 'discretion', 'in', 'your', 'entertainment', 'choices', ',', "you're", 'interested', 'in', 'anne', 'geddes', ',', 'john', 'grisham', ',', 'and', 'thomas', 'kincaid', '.']
# [('entertainment', 2.0)]
# 2.0
# ['we', 'get', 'the', 'comedy', 'we', 'settle', 'for', '.']
# [('comedy', 1.0)]
# 1.0
# ['the', 'uneven', 'movie', 'does', 'have', 'its', 'charms', 'and', 'its', 'funny', 'moments', 'but', 'not', 'quite', 'enough', 'of', 'them', '.']
# [('uneven', -1.0), ('funny', 3.0), ('enough', 1.1)]
# 3.1
# ['two', 'hours', 'of', 'sepia-tinted', 'heavy', 'metal', 'images', 'and', 'surround', 'sound', 'effects', 'of', 'people', 'moaning', '.']
# [('heavy', -1.0), ('sound', 1.0)]
# 0.0
# ['the', 'campy', 'results', 'make', 'mel', "brooks'", 'borscht', 'belt', 'schtick', 'look', 'sophisticated', '.']
# [('campy', -1.0), ('sophisticated', 3.0)]
# 2.0
# ['the', 'hanukkah', 'spirit', 'seems', 'fried', 'in', 'pork', '.']
# []
# 0
# ['cherish', "would've", 'worked', 'a', 'lot', 'better', 'had', 'it', 'been', 'a', 'short', 'film', '.']
# [('cherish', 3.0), ('better', 2.0), ('short', -1.0)]
# 4.0
# ['the', 'plot', 'is', 'paper-thin', 'and', 'the', 'characters', "aren't", 'interesting', 'enough', 'to', 'watch', 'them', 'go', 'about', 'their', 'daily', 'activities', 'for', 'two', 'whole', 'hours', '.']
# [('paper-thin', -1.0), ('interesting', 3.0), ('enough', 1.0)]
# 3.0
# ["kaufman's", 'script', 'is', 'never', 'especially', 'clever', 'and', 'often', 'is', 'rather', 'pretentious', '.']
# [('clever', 3.9000000000000004), ('pretentious', -2.7)]
# 1.2000000000000002
# ['the', 'film', "didn't", 'move', 'me', 'one', 'way', 'or', 'the', 'other', ',', 'but', 'it', 'was', 'an', 'honest', 'effort', 'and', 'if', 'you', 'want', 'to', 'see', 'a', 'flick', 'about', 'telemarketers', 'this', 'one', 'will', 'due', '.']
# [('honest', 2.0), ('flick', -2.0)]
# 0.0
# ['it', 'collapses', 'when', 'mr', '.', 'taylor', 'tries', 'to', 'shift', 'the', 'tone', 'to', 'a', "thriller's", 'rush', '.']
# []
# 0
# ['.', '.', '.', 'blade', 'ii', 'is', 'still', 'top-heavy', 'with', 'blazing', 'guns', ',', 'cheatfully', 'filmed', 'martial', 'arts', ',', 'disintegrating', 'bloodsucker', 'computer', 'effects', 'and', 'jagged', 'camera', 'moves', 'that', 'serve', 'no', 'other', 'purpose', 'than', 'to', 'call', 'attention', 'to', 'themselves', '.']
# []
# 0
# ['no', 'surprises', '.']
# []
# 0
# ['this', "director's", 'cut', '--', 'which', 'adds', '51', 'minutes', '--', 'takes', 'a', 'great', 'film', 'and', 'turns', 'it', 'into', 'a', 'mundane', 'soap', 'opera', '.']
# [('great', 4.0), ('mundane', -3.0)]
# 1.0
# ['the', 'venezuelans', 'say', 'things', 'like', '"', 'si', ',', 'pretty', 'much', '"', 'and', '"', 'por', 'favor', ',', 'go', 'home', '"', 'when', 'talking', 'to', 'americans', '.', "that's", 'muy', 'loco', ',', 'but', 'no', 'more', 'ridiculous', 'than', 'most', 'of', 'the', 'rest', 'of', '"', 'dragonfly', '.', '"']
# [('like', 1.0), ('pretty', 2.0), ('favor', 2.0), ('ridiculous', -1.5)]
# 3.5
# ['director', 'tom', 'shadyac', 'and', 'star', 'kevin', 'costner', 'glumly', 'mishandle', 'the', "story's", 'promising', 'premise', 'of', 'a', 'physician', 'who', 'needs', 'to', 'heal', 'himself', '.']
# [('glumly', -2.0), ('mishandle', -1.0), ('promising', 2.0), ('heal', 2.0)]
# 1.0
# ['like', 'the', 'tuck', 'family', 'themselves', ',', 'this', 'movie', 'just', 'goes', 'on', 'and', 'on', 'and', 'on', 'and', 'on']
# [('like', 1.0), ('just', 1.0)]
# 2.0
# ['a', 'film', 'that', 'plays', 'things', 'so', 'nice', "'n", 'safe', 'as', 'to', 'often', 'play', 'like', 'a', 'milquetoast', 'movie', 'of', 'the', 'week', 'blown', 'up', 'for', 'the', 'big', 'screen', '.']
# [('nice', 2.8), ('safe', 1.0), ('like', 1.0), ('big', 1.0)]
# 5.8
# ["it's", 'a', 'feel-bad', 'ending', 'for', 'a', 'depressing', 'story', 'that', 'throws', 'a', 'bunch', 'of', 'hot-button', 'items', 'in', 'the', "viewer's", 'face', 'and', 'asks', 'to', 'be', 'seen', 'as', 'hip', ',', 'winking', 'social', 'commentary', '.']
# [('depressing', -2.0), ('hip', 2.0), ('social', 1.0)]
# 1.0
# ['put', 'it', 'somewhere', 'between', 'sling', 'blade', 'and', 'south', 'of', 'heaven', ',', 'west', 'of', 'hell', 'in', 'the', 'pantheon', 'of', 'billy', "bob's", 'body', 'of', 'work', '.']
# [('heaven', 3.0), ('hell', -3.0)]
# 0.0
# ['you', 'come', 'away', 'thinking', 'not', 'only', 'that', 'kate', "isn't", 'very', 'bright', ',', 'but', 'that', 'she', "hasn't", 'been', 'worth', 'caring', 'about', 'and', 'that', 'maybe', 'she', ',', 'janine', 'and', 'molly', '--', 'an', 'all-woman', 'dysfunctional', 'family', '--', 'deserve', 'one', 'another', '.']
# [('bright', 3.5999999999999996), ('worth', 2.0), ('dysfunctional', -3.0), ('deserve', 2.0)]
# 4.6
# ['the', 'attempt', 'to', 'build', 'up', 'a', 'pressure', 'cooker', 'of', 'horrified', 'awe', 'emerges', 'from', 'the', 'simple', 'fact', 'that', 'the', 'movie', 'has', 'virtually', 'nothing', 'to', 'show', '.']
# [('attempt', -1.0), ('pressure', -1.0), ('awe', 4.0)]
# 2.0
# ["it's", 'provocative', 'stuff', ',', 'but', 'the', 'speculative', 'effort', 'is', 'hampered', 'by', "taylor's", 'cartoonish', 'performance', 'and', 'the', "film's", 'ill-considered', 'notion', 'that', "hitler's", 'destiny', 'was', 'shaped', 'by', 'the', 'most', 'random', 'of', 'chances', '.']
# []
# 0
# ['a', 'cellophane-pop', 'remake', 'of', 'the', 'punk', 'classic', 'ladies', 'and', 'gentlemen', ',', 'the', 'fabulous', 'stains', '.', '.', '.', 'crossroads', 'is', 'never', 'much', 'worse', 'than', 'bland', 'or', 'better', 'than', 'inconsequential', '.']
# [('punk', -2.0), ('classic', 4.0), ('fabulous', 5.0), ('worse', -4.8), ('bland', -2.0), ('better', 2.0)]
# 2.2
# ['for', 'this', 'sort', 'of', 'thing', 'to', 'work', ',', 'we', 'need', 'agile', 'performers', ',', 'but', 'the', 'proficient', ',', 'dull', 'sorvino', 'has', 'no', 'light', 'touch', ',', 'and', 'rodan', 'is', 'out', 'of', 'his', 'league', '.']
# [('agile', 1.0), ('proficient', 2.0), ('dull', -2.0)]
# 1.0
# ["it's", 'so', 'downbeat', 'and', 'nearly', 'humorless', 'that', 'it', 'becomes', 'a', 'chore', 'to', 'sit', 'through', '--', 'despite', 'some', 'first-rate', 'performances', 'by', 'its', 'lead', '.']
# [('chore', -3.0), ('first-rate', 3.2)]
# 0.20000000000000018
# ['there', 'are', 'many', 'definitions', 'of', "'time", "waster'", 'but', 'this', 'movie', 'must', 'surely', 'be', 'one', 'of', 'them', '.']
# [('surely', 1.0)]
# 1.0
# ['the', 'thing', 'looks', 'like', 'a', 'made-for-home-video', 'quickie', '.']
# [('like', 1.0)]
# 1.0

# %% [markdown]
# #### 4.2
# rubric={reasoning:3}
#
# Identify 3 categories of errors that you see. They should NOT be issues with specific dictionary entries, but something more general. For each of the three types of errors, include 3 examples of the error (the sentence, with some indicator of the relevant word(s))

# %% [markdown]
# Answer:
